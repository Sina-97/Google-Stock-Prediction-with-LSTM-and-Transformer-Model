# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from statsmodels.tsa.seasonal import STL
import scipy.stats
from sklearn.metrics import mean_squared_error, mean_absolute_error

import statsmodels.tsa.stattools as sts

from tensorflow.keras import Sequential
from tensorflow.keras.layers import LSTM, Dense
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping

import time

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Processing

# %%
path = '/content/drive/MyDrive/google ADA/GOOGL_2006-01-01_to_2018-01-01.csv'
df = pd.read_csv(path)
df.head()
# Out:
#          Date    Open    High     Low   Close    Volume   Name
# 0  2006-01-03  211.47  218.05  209.32  217.83  13137450  GOOGL
# 1  2006-01-04  222.17  224.70  220.09  222.84  15292353  GOOGL
# 2  2006-01-05  223.22  226.00  220.97  225.85  10815661  GOOGL
# 3  2006-01-06  228.66  235.49  226.85  233.06  17759521  GOOGL
# 4  2006-01-09  233.44  236.94  230.70  233.68  12795837  GOOGL

# %%
# Converting Date column to datetime
df['Date'] = pd.to_datetime(df.Date, yearfirst=True)
df.head()
# Out:
#         Date    Open    High     Low   Close    Volume   Name
# 0 2006-01-03  211.47  218.05  209.32  217.83  13137450  GOOGL
# 1 2006-01-04  222.17  224.70  220.09  222.84  15292353  GOOGL
# 2 2006-01-05  223.22  226.00  220.97  225.85  10815661  GOOGL
# 3 2006-01-06  228.66  235.49  226.85  233.06  17759521  GOOGL
# 4 2006-01-09  233.44  236.94  230.70  233.68  12795837  GOOGL

# %%
df.set_index('Date', inplace=True) # Setting the index to date

df = df.asfreq('b') # Setting the frequency to business days

df.drop('Name', axis=1, inplace=True) # Dropping useless columns

# %% [markdown]
# # Checking clusters of NaN and filling NaN

# %%
# Create a boolean mask for NaN values
nan_mask = df['Open'].isna()

# Check for consecutive NaN values using the shift() function
consecutive_nan_mask = nan_mask & nan_mask.shift(-1)

consecutive_nan_mask.sum() # Checking how many consecutive nan there are
# Out:
# 3

# %%
df[(df.index.day < 5) * (df.index.month == 1) * (df.index.year == 2007)]
# Out:
#               Open    High     Low   Close     Volume
# Date
# 2007-01-01     NaN     NaN     NaN     NaN        NaN
# 2007-01-02     NaN     NaN     NaN     NaN        NaN
# 2007-01-03  233.23  238.57  230.79  234.03  7722839.0
# 2007-01-04  234.73  242.22  234.41  241.87  7916458.0

# %%
df[(df.index.day < 6) * (df.index.month == 4) * (df.index.year == 2010)]
# Out:
#               Open    High     Low   Close     Volume
# Date
# 2010-04-01     NaN     NaN     NaN     NaN        NaN
# 2010-04-02     NaN     NaN     NaN     NaN        NaN
# 2010-04-05  285.74  287.73  284.78  285.79  1902063.0

# %%
df[(df.index.day > 25) * (df.index.month == 10) * (df.index.year == 2012)]
# Out:
#               Open    High     Low   Close     Volume
# Date
# 2012-10-26  338.59  341.86  335.94  337.91  1950865.0
# 2012-10-29     NaN     NaN     NaN     NaN        NaN
# 2012-10-30     NaN     NaN     NaN     NaN        NaN
# 2012-10-31  340.27  340.84  337.84  340.49  1537001.0

# %%
df[consecutive_nan_mask]
# Out:
#             Open  High  Low  Close  Volume
# Date
# 2007-01-01   NaN   NaN  NaN    NaN     NaN
# 2010-04-01   NaN   NaN  NaN    NaN     NaN
# 2012-10-29   NaN   NaN  NaN    NaN     NaN

# %%
aux = df[consecutive_nan_mask]
df = df[~consecutive_nan_mask]

# %%
df = df.fillna(method='bfill') # Backfilling

# Adding the other samples
df = df.asfreq('b')
df = df.fillna(method='ffill') # Sampling them using frontfill

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
input_vars = df.shape[1]

# %% [markdown]
# # Normalization

# %%
train_size = 0.8
val_size = 0.1
train_samples = int(df.shape[0]*train_size)
val_samples = int(df.shape[0]*(train_size+val_size))

scaler = StandardScaler()
df.iloc[:train_samples] = scaler.fit_transform(df.iloc[:train_samples])
df.iloc[train_samples:] = scaler.transform(df.iloc[train_samples:])

# %%
df.head()
# Out:
#                 Open      High       Low     Close    Volume
# Date
# 2006-01-03 -0.904145 -0.873545 -0.899456 -0.854099  2.876012
# 2006-01-04 -0.821233 -0.822217 -0.815559 -0.815269  3.550220
# 2006-01-05 -0.813096 -0.812183 -0.808704 -0.791940  2.149591
# 2006-01-06 -0.770943 -0.738935 -0.762899 -0.736059  4.322127
# 2006-01-09 -0.733903 -0.727743 -0.732908 -0.731253  2.769132

# %% [markdown]
# # Lagging variables

# %%
n_lagged = 50

# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    # n_in = number of lagged variables in the past
    # n_out = number of lagged variables in the future
    n_vars = 1 if type(data) is list else data.shape[1]
    df = data
    cols, names = list(), list()
    col_names = data.columns
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [(col_names[j]+'(t-%d)' % (i,)) for j in range(n_vars)]
        # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [col_names[j]+'(t)' for j in range(n_vars)]
        else:
            names += [(col_names[j]+'(t+%d)' % (i,)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# frame as supervised learning
reframed = series_to_supervised(df, n_lagged, 1)
# drop columns we don't want to predict
reframed.head()
print(reframed.shape)
# Out:
# (3079, 255)

# %%
# At time "t", we only have Open(t) and want to predict Close(t), so we can drop High(t), Volume(t) and Low(t)
# Also we will drop Open(t-1) because each time step needs to have exactly 4 variables. If we add more time steps we will have
# a remaining Variable (Open(t)) to spare, so we will replace Open(t-1) with Open(t) for the first lagged variable.
reframed.drop(['High(t)', 'Low(t)', 'Volume(t)', 'Open(t-'+str(n_lagged)+')'], axis=1, inplace=True)
reframed.head()
# Out:
#             High(t-50)  Low(t-50)  Close(t-50)  Volume(t-50)  Open(t-49)  \
# Date
# 2006-03-14   -0.873545  -0.899456    -0.854099      2.876012   -0.821233
# 2006-03-15   -0.822217  -0.815559    -0.815269      3.550220   -0.813096
# 2006-03-16   -0.812183  -0.808704    -0.791940      2.149591   -0.770943
# 2006-03-17   -0.738935  -0.762899    -0.736059      4.322127   -0.733903
# 2006-03-20   -0.727743  -0.732908    -0.731253      2.769132   -0.741652
#
#             High(t-49)  Low(t-49)  Close(t-49)  Volume(t-49)  Open(t-48)  ...  \
# Date                                                                      ...
# 2006-03-14   -0.822217  -0.815559    -0.815269      3.550220   -0.813096  ...
# 2006-03-15   -0.812183  -0.808704    -0.791940      2.149591   -0.770943  ...
# 2006-03-16   -0.738935  -0.762899    -0.736059      4.322127   -0.733903  ...
# 2006-03-17   -0.727743  -0.732908    -0.731253      2.769132   -0.741652  ...
# 2006-03-20   -0.739938  -0.728624    -0.720170      1.614286   -0.715074  ...
#
#             Low(t-2)  Close(t-2)  Volume(t-2)  Open(t-1)  High(t-1)  Low(t-1)  \
# Date
# 2006-03-14 -1.237381   -1.233175     4.815238  -1.220530  -1.219563 -1.222191
# 2006-03-15 -1.222191   -1.234880     3.035635  -1.235253  -1.195327 -1.233175
# 2006-03-16 -1.233175   -1.180162     4.542192  -1.182406  -1.195558 -1.202327
# 2006-03-17 -1.202327   -1.206048     2.761922  -1.190775  -1.209297 -1.212609
# 2006-03-20 -1.212609   -1.228292     1.901114  -1.228821  -1.236235 -1.224216
#
#             Close(t-1)  Volume(t-1)   Open(t)  Close(t)
# Date
# 2006-03-14   -1.234880     3.035635 -1.235253 -1.180162
# 2006-03-15   -1.180162     4.542192 -1.182406 -1.206048
# 2006-03-16   -1.206048     2.761922 -1.190775 -1.228292
# 2006-03-17   -1.228292     1.901114 -1.228821 -1.224339
# 2006-03-20   -1.224339     1.443441 -1.215106 -1.191710
#
# [5 rows x 251 columns]

# %% [markdown]
# # Data splitting

# %%
train_X, train_y = reframed.iloc[:train_samples, :-1].values, reframed.iloc[:train_samples, -1].values
val_X, val_y = reframed.iloc[train_samples:val_samples, :-1].values, reframed.iloc[train_samples:val_samples, -1].values
test_X, test_y = reframed.iloc[val_samples:, :-1].values, reframed.iloc[val_samples:, -1].values

# %% [markdown]
# # Reshaping data for LSTM

# %%
train_X = train_X.reshape((train_X.shape[0], n_lagged, input_vars))
val_X = val_X.reshape((val_X.shape[0], n_lagged, input_vars))
test_X = test_X.reshape((test_X.shape[0], n_lagged, input_vars))

# %%
train_X.shape
# Out:
# (2503, 50, 5)

# %% [markdown]
# # LSTM

# %%
hidden_layer_neurons = 500
batch_size = 32
epochs = 100
learning_rate = 0.0005

# Optimizer and callbacks
optimizer = Adam(learning_rate=learning_rate)
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)


# Defining model
model = Sequential()
model.add(LSTM(hidden_layer_neurons, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1)) # Output layer
model.compile(loss='mse', optimizer=optimizer)

# Fit network
t0 = time.time()
history = model.fit(train_X, train_y, epochs=epochs, batch_size=batch_size,
                    validation_data=(val_X, val_y), verbose=2, shuffle=False,
                   callbacks = [early_stopping])
t1 = time.time()
print("Total execution time:", t1-t0)
lstm_training_time = t1-t0

# Plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 79/79 - 3s - loss: 0.0447 - val_loss: 0.0152 - 3s/epoch - 36ms/step
# Epoch 2/100
# 79/79 - 1s - loss: 0.0103 - val_loss: 0.0156 - 647ms/epoch - 8ms/step
# Epoch 3/100
# 79/79 - 1s - loss: 0.0073 - val_loss: 0.0118 - 654ms/epoch - 8ms/step
# Epoch 4/100
# 79/79 - 1s - loss: 0.0065 - val_loss: 0.0113 - 673ms/epoch - 9ms/step
# Epoch 5/100
# 79/79 - 1s - loss: 0.0057 - val_loss: 0.0104 - 655ms/epoch - 8ms/step
# Epoch 6/100
# 79/79 - 1s - loss: 0.0049 - val_loss: 0.0098 - 732ms/epoch - 9ms/step
# Epoch 7/100
# 79/79 - 1s - loss: 0.0044 - val_loss: 0.0089 - 745ms/epoch - 9ms/step
# Epoch 8/100
# 79/79 - 1s - loss: 0.0041 - val_loss: 0.0083 - 763ms/epoch - 10ms/step
# Epoch 9/100
# 79/79 - 1s - loss: 0.0038 - val_loss: 0.0079 - 768ms/epoch - 10ms/step
# Epoch 10/100
# 79/79 - 1s - loss: 0.0035 - val_loss: 0.0083 - 748ms/epoch - 9ms/step
# Epoch 11/100
# 79/79 - 1s - loss: 0.0034 - val_loss: 0.0121 - 751ms/epoch - 10ms/step
# Epoch 12/100
# 79/79 - 1s - loss: 0.0041 - val_loss: 0.0070 - 667ms/epoch - 8ms/step
# Epoch 13/100
# 79/79 - 1s - loss: 0.0048 - val_loss: 0.0226 - 661ms/epoch - 8ms/step
# Epoch 14/100
# 79/79 - 1s - loss: 0.0049 - val_loss: 0.0074 - 679ms/epoch - 9ms/step
# Epoch 15/100
# 79/79 - 1s - loss: 0.0037 - val_loss: 0.0064 - 682ms/epoch - 9ms/step
# Epoch 16/100
# 79/79 - 1s - loss: 0.0029 - val_loss: 0.0061 - 657ms/epoch - 8ms/step
# Epoch 17/100
# 79/79 - 1s - loss: 0.0029 - val_loss: 0.0059 - 663ms/epoch - 8ms/step
# Epoch 18/100
# 79/79 - 1s - loss: 0.0028 - val_loss: 0.0057 - 661ms/epoch - 8ms/step
# Epoch 19/100
# 79/79 - 1s - loss: 0.0027 - val_loss: 0.0054 - 670ms/epoch - 8ms/step
# Epoch 20/100
# 79/79 - 1s - loss: 0.0027 - val_loss: 0.0052 - 676ms/epoch - 9ms/step
# Epoch 21/100
# 79/79 - 1s - loss: 0.0026 - val_loss: 0.0050 - 660ms/epoch - 8ms/step
# Epoch 22/100
# 79/79 - 1s - loss: 0.0025 - val_loss: 0.0049 - 692ms/epoch - 9ms/step
# Epoch 23/100
# 79/79 - 1s - loss: 0.0025 - val_loss: 0.0049 - 683ms/epoch - 9ms/step
# Epoch 24/100
# 79/79 - 1s - loss: 0.0024 - val_loss: 0.0050 - 688ms/epoch - 9ms/step
# Epoch 25/100
# 79/79 - 1s - loss: 0.0023 - val_loss: 0.0050 - 662ms/epoch - 8ms/step
# Epoch 26/100
# 79/79 - 1s - loss: 0.0023 - val_loss: 0.0049 - 710ms/epoch - 9ms/step
# Epoch 27/100
# 79/79 - 1s - loss: 0.0024 - val_loss: 0.0047 - 758ms/epoch - 10ms/step
# Epoch 28/100
# 79/79 - 1s - loss: 0.0024 - val_loss: 0.0047 - 757ms/epoch - 10ms/step
# Epoch 29/100
# 79/79 - 1s - loss: 0.0025 - val_loss: 0.0054 - 759ms/epoch - 10ms/step
# Epoch 30/100
# 79/79 - 1s - loss: 0.0022 - val_loss: 0.0045 - 760ms/epoch - 10ms/step
# Epoch 31/100
# 79/79 - 1s - loss: 0.0025 - val_loss: 0.0053 - 768ms/epoch - 10ms/step
# Epoch 32/100
# 79/79 - 1s - loss: 0.0023 - val_loss: 0.0048 - 716ms/epoch - 9ms/step
# Epoch 33/100
# 79/79 - 1s - loss: 0.0022 - val_loss: 0.0051 - 660ms/epoch - 8ms/step
# Epoch 34/100
# 79/79 - 1s - loss: 0.0021 - val_loss: 0.0040 - 690ms/epoch - 9ms/step
# Epoch 35/100
# 79/79 - 1s - loss: 0.0022 - val_loss: 0.0043 - 686ms/epoch - 9ms/step
# Epoch 36/100
# 79/79 - 1s - loss: 0.0020 - val_loss: 0.0045 - 663ms/epoch - 8ms/step
# Epoch 37/100
# 79/79 - 1s - loss: 0.0020 - val_loss: 0.0048 - 660ms/epoch - 8ms/step
# Epoch 38/100
# 79/79 - 1s - loss: 0.0020 - val_loss: 0.0043 - 664ms/epoch - 8ms/step
# Epoch 39/100
# 79/79 - 1s - loss: 0.0023 - val_loss: 0.0045 - 689ms/epoch - 9ms/step
# Epoch 40/100
# 79/79 - 1s - loss: 0.0019 - val_loss: 0.0042 - 728ms/epoch - 9ms/step
# Epoch 41/100
# 79/79 - 1s - loss: 0.0020 - val_loss: 0.0048 - 691ms/epoch - 9ms/step
# Epoch 42/100
# 79/79 - 1s - loss: 0.0017 - val_loss: 0.0042 - 728ms/epoch - 9ms/step
# Epoch 43/100
# 79/79 - 1s - loss: 0.0018 - val_loss: 0.0042 - 803ms/epoch - 10ms/step
# Epoch 44/100
# 79/79 - 1s - loss: 0.0019 - val_loss: 0.0042 - 800ms/epoch - 10ms/step
# Total execution time: 33.25967764854431

# %%
from keras.utils import plot_model
plot_model(model, show_shapes=True, show_layer_names=True, show_layer_activations=True)

# %% [markdown]
# # Predicting

# %%
mean = scaler.mean_[scaler.feature_names_in_ == 'Close'][0]
std = np.sqrt(scaler.var_[scaler.feature_names_in_ == 'Close'][0])

# %%
plt.subplots(figsize=(10, 5))

# make a prediction
yhat_train = model.predict(train_X).flatten()
yhat_val = model.predict(val_X).flatten()
yhat_test = model.predict(test_X).flatten()

# Concatenate the results
y_pred = np.concatenate([yhat_train, yhat_val, yhat_test])* std + mean
y_real = np.concatenate([train_y, val_y, test_y]) * std + mean

# Plot
plt.plot(df.iloc[n_lagged:].index, y_pred, label='Predicted')
plt.plot(df.iloc[n_lagged:].index, y_real, label='Real')

plt.axvline(x = df.iloc[[train_samples]].index, color = 'yellow', label = 'Validation')
plt.axvline(x = df.iloc[[val_samples]].index, color = 'red', label = 'Test')

plt.legend()
plt.xlabel("Date")
plt.ylabel("Closing Stock price")
plt.title("LSTM Results")
plt.show()
# Out:
# 79/79 [==============================] - 1s 6ms/step
# 10/10 [==============================] - 0s 5ms/step
# 9/9 [==============================] - 0s 4ms/step

# %%
# Getting metrics
# MSE
train_rmse = np.sqrt( mean_squared_error( y_real[:train_samples], y_pred[:train_samples] ) )
val_rmse = np.sqrt( mean_squared_error( y_real[train_samples:val_samples], y_pred[train_samples:val_samples] ) )
test_rmse = np.sqrt( mean_squared_error( y_real[val_samples:], y_pred[val_samples:] ) )

# MAE
train_mae = mean_absolute_error( y_real[:train_samples], y_pred[:train_samples] )
val_mae = mean_absolute_error( y_real[train_samples:val_samples], y_pred[train_samples:val_samples] )
test_mae = mean_absolute_error( y_real[val_samples:], y_pred[val_samples:] )

# %%
print(test_mae, test_rmse)
# Out:
# 17.567387277581396 20.697801338001412

# %%
print(val_mae, val_rmse)
# Out:
# 6.0885468718799896 8.12002789122835

# %%
print(train_mae, train_rmse)
# Out:
# 5.0556662898077 7.0168259799133

# %%
# Plot
plt.plot(df.iloc[n_lagged+val_samples:].index, y_pred[val_samples:], label='Predicted')
plt.plot(df.iloc[n_lagged+val_samples:].index, y_real[val_samples:], label='Real')


plt.legend()
plt.xlabel("Date")
plt.ylabel("Closing Stock price")
plt.title("LSTM Results for Test set")
plt.show()

# %%
aux = pd.read_csv(path)

# %%
np.mean((aux.iloc[train_samples: val_samples]['Open'] - aux.iloc[train_samples: val_samples]['Close']))
# Out:
# 0.28335463258785926

# %%
mean_absolute_error(aux.iloc[val_samples:]['Open'] + 0.28, aux.iloc[val_samples:]['Close'])
# Out:
# 5.830394088669956

# %%
test_rmse_LSTM = test_rmse
test_mae_LSTM = test_mae
val_rmse_LSTM = val_rmse
val_mae_LSTM = val_mae
train_rmse_LSTM = train_rmse
train_mae_LSTM = train_mae

# %% [markdown]
# # Sensitivity Study For LSTM: Learning Rate & Number of Neurons

# %%
hidden_layer_neurons = [300,500,700]
batch_size = 32
epochs = 50
learning_rate = [0.001,0.0005,0.0001]
n=0
hyperparameters = []
rmse_test_list = []
rmse_val_list = []
rmse_train_list = []
mean = scaler.mean_[scaler.feature_names_in_ == 'Close'][0]
std = np.sqrt(scaler.var_[scaler.feature_names_in_ == 'Close'][0])
# Optimizer and callbacks
for learn_rate in learning_rate:
    for hidden_neuron in hidden_layer_neurons:
        optimizer = Adam(learning_rate=learn_rate)
        early_stopping = EarlyStopping(monitor='val_loss', patience=7, restore_best_weights=True)


        # Defining model
        model = Sequential()
        model.add(LSTM(hidden_neuron, input_shape=(train_X.shape[1], train_X.shape[2])))
        model.add(Dense(1)) # Output layer
        model.compile(loss='mse', optimizer=optimizer)

        # Fit network
        t0 = time.time()
        history = model.fit(train_X, train_y, epochs=epochs, batch_size=batch_size,
                            validation_data=(val_X, val_y), verbose=2, shuffle=False,
                        callbacks = [early_stopping])
        t1 = time.time()
        print("Total execution time:", t1-t0)
        lstm_training_time = t1-t0

    # make a prediction
        yhat_train = model.predict(train_X).flatten()
        yhat_val = model.predict(val_X).flatten()
        yhat_test = model.predict(test_X).flatten()

# Concatenate the results
        y_pred = np.concatenate([yhat_train, yhat_val, yhat_test])* std + mean
        y_real = np.concatenate([train_y, val_y, test_y]) * std + mean
        train_rmse = np.sqrt( mean_squared_error( y_real[:train_samples], y_pred[:train_samples] ) )
        val_rmse = np.sqrt( mean_squared_error( y_real[train_samples:val_samples], y_pred[train_samples:val_samples] ) )
        test_rmse = np.sqrt( mean_squared_error( y_real[val_samples:], y_pred[val_samples:] ) )
        rmse_test_list.append(test_rmse)
        rmse_val_list.append(val_rmse)
        rmse_train_list.append(train_rmse)
        hyperparameters.append([learn_rate,hidden_neuron])
        n+=1


df_results_lstm = pd.DataFrame(hyperparameters, columns=['Learning Rate', 'Hidden Neurons'])
df_results_lstm['Test RMSE'] = rmse_test_list
df_results_lstm['Val RMSE'] = rmse_val_list
df_results_lstm['Train RMSE'] = rmse_train_list
print(df_results_lstm)
# Out:
# Epoch 1/50
# 79/79 - 5s - loss: 0.0416 - val_loss: 0.0676 - 5s/epoch - 61ms/step
# Epoch 2/50
# 79/79 - 1s - loss: 0.0089 - val_loss: 0.0313 - 557ms/epoch - 7ms/step
# Epoch 3/50
# 79/79 - 1s - loss: 0.0067 - val_loss: 0.0130 - 556ms/epoch - 7ms/step
# Epoch 4/50
# 79/79 - 1s - loss: 0.0050 - val_loss: 0.0092 - 555ms/epoch - 7ms/step
# Epoch 5/50
# 79/79 - 1s - loss: 0.0043 - val_loss: 0.0103 - 576ms/epoch - 7ms/step
# Epoch 6/50
# 79/79 - 0s - loss: 0.0038 - val_loss: 0.0133 - 433ms/epoch - 5ms/step
# Epoch 7/50
# 79/79 - 0s - loss: 0.0036 - val_loss: 0.0192 - 448ms/epoch - 6ms/step
# Epoch 8/50
# 79/79 - 0s - loss: 0.0043 - val_loss: 0.0099 - 422ms/epoch - 5ms/step
# Epoch 9/50
# 79/79 - 0s - loss: 0.0063 - val_loss: 0.0386 - 417ms/epoch - 5ms/step
# Epoch 10/50
# 79/79 - 0s - loss: 0.0064 - val_loss: 0.0062 - 450ms/epoch - 6ms/step
# Epoch 11/50
# 79/79 - 0s - loss: 0.0062 - val_loss: 0.0084 - 446ms/epoch - 6ms/step
# Epoch 12/50
# 79/79 - 0s - loss: 0.0035 - val_loss: 0.0058 - 410ms/epoch - 5ms/step
# Epoch 13/50
# 79/79 - 0s - loss: 0.0029 - val_loss: 0.0055 - 451ms/epoch - 6ms/step
# Epoch 14/50
# 79/79 - 0s - loss: 0.0028 - val_loss: 0.0052 - 458ms/epoch - 6ms/step
# Epoch 15/50
# 79/79 - 0s - loss: 0.0029 - val_loss: 0.0051 - 414ms/epoch - 5ms/step
# Epoch 16/50
# 79/79 - 0s - loss: 0.0028 - val_loss: 0.0051 - 451ms/epoch - 6ms/step
# Epoch 17/50
# 79/79 - 0s - loss: 0.0028 - val_loss: 0.0051 - 410ms/epoch - 5ms/step
# Epoch 18/50
# 79/79 - 0s - loss: 0.0028 - val_loss: 0.0052 - 423ms/epoch - 5ms/step
# Epoch 19/50
# 79/79 - 0s - loss: 0.0028 - val_loss: 0.0056 - 408ms/epoch - 5ms/step
# Epoch 20/50
# 79/79 - 0s - loss: 0.0028 - val_loss: 0.0062 - 468ms/epoch - 6ms/step
# Epoch 21/50
# 79/79 - 0s - loss: 0.0029 - val_loss: 0.0067 - 407ms/epoch - 5ms/step
# Epoch 22/50
# 79/79 - 0s - loss: 0.0029 - val_loss: 0.0068 - 439ms/epoch - 6ms/step
# Epoch 23/50
# 79/79 - 0s - loss: 0.0029 - val_loss: 0.0079 - 452ms/epoch - 6ms/step
# Total execution time: 15.020550966262817
# 79/79 [==============================] - 1s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# Epoch 1/50
# 79/79 - 4s - loss: 0.0260 - val_loss: 0.0112 - 4s/epoch - 50ms/step
# Epoch 2/50
# 79/79 - 1s - loss: 0.0063 - val_loss: 0.0174 - 746ms/epoch - 9ms/step
# Epoch 3/50
# 79/79 - 1s - loss: 0.0047 - val_loss: 0.0132 - 733ms/epoch - 9ms/step
# Epoch 4/50
# 79/79 - 1s - loss: 0.0050 - val_loss: 0.0180 - 646ms/epoch - 8ms/step
# Epoch 5/50
# 79/79 - 1s - loss: 0.0086 - val_loss: 0.0351 - 647ms/epoch - 8ms/step
# Epoch 6/50
# 79/79 - 1s - loss: 0.0076 - val_loss: 0.0068 - 624ms/epoch - 8ms/step
# Epoch 7/50
# 79/79 - 1s - loss: 0.0036 - val_loss: 0.0071 - 631ms/epoch - 8ms/step
# Epoch 8/50
# 79/79 - 1s - loss: 0.0033 - val_loss: 0.0066 - 660ms/epoch - 8ms/step
# Epoch 9/50
# 79/79 - 1s - loss: 0.0031 - val_loss: 0.0063 - 653ms/epoch - 8ms/step
# Epoch 10/50
# 79/79 - 1s - loss: 0.0030 - val_loss: 0.0067 - 647ms/epoch - 8ms/step
# Epoch 11/50
# 79/79 - 1s - loss: 0.0029 - val_loss: 0.0072 - 645ms/epoch - 8ms/step
# Epoch 12/50
# 79/79 - 1s - loss: 0.0028 - val_loss: 0.0071 - 628ms/epoch - 8ms/step
# Epoch 13/50
# 79/79 - 1s - loss: 0.0027 - val_loss: 0.0072 - 666ms/epoch - 8ms/step
# Epoch 14/50
# 79/79 - 1s - loss: 0.0027 - val_loss: 0.0074 - 647ms/epoch - 8ms/step
# Epoch 15/50
# 79/79 - 1s - loss: 0.0026 - val_loss: 0.0071 - 631ms/epoch - 8ms/step
# Epoch 16/50
# 79/79 - 1s - loss: 0.0027 - val_loss: 0.0063 - 654ms/epoch - 8ms/step
# Total execution time: 13.936565637588501
# 79/79 [==============================] - 1s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 9/9 [==============================] - 0s 3ms/step
# Epoch 1/50
# 79/79 - 5s - loss: 0.0361 - val_loss: 0.0504 - 5s/epoch - 61ms/step
# Epoch 2/50
# 79/79 - 1s - loss: 0.0079 - val_loss: 0.0356 - 1s/epoch - 13ms/step
# Epoch 3/50
# 79/79 - 1s - loss: 0.0076 - val_loss: 0.0226 - 1s/epoch - 13ms/step
# Epoch 4/50
# 79/79 - 1s - loss: 0.0064 - val_loss: 0.0092 - 1s/epoch - 13ms/step
# Epoch 5/50
# 79/79 - 1s - loss: 0.0059 - val_loss: 0.0091 - 1s/epoch - 13ms/step
# Epoch 6/50
# 79/79 - 1s - loss: 0.0057 - val_loss: 0.0090 - 1s/epoch - 13ms/step
# Epoch 7/50
# 79/79 - 1s - loss: 0.0051 - val_loss: 0.0164 - 1s/epoch - 13ms/step
# Epoch 8/50
# 79/79 - 1s - loss: 0.0048 - val_loss: 0.0365 - 1s/epoch - 13ms/step
# Epoch 9/50
# 79/79 - 1s - loss: 0.0050 - val_loss: 0.0111 - 1s/epoch - 13ms/step
# Epoch 10/50
# 79/79 - 1s - loss: 0.0054 - val_loss: 0.0063 - 1s/epoch - 13ms/step
# Epoch 11/50
# 79/79 - 1s - loss: 0.0044 - val_loss: 0.0094 - 1s/epoch - 13ms/step
# Epoch 12/50
# 79/79 - 1s - loss: 0.0038 - val_loss: 0.0068 - 1s/epoch - 14ms/step
# Epoch 13/50
# 79/79 - 1s - loss: 0.0032 - val_loss: 0.0049 - 1s/epoch - 14ms/step
# Epoch 14/50
# 79/79 - 1s - loss: 0.0026 - val_loss: 0.0047 - 1s/epoch - 14ms/step
# Epoch 15/50
# 79/79 - 1s - loss: 0.0028 - val_loss: 0.0049 - 1s/epoch - 13ms/step
# Epoch 16/50
# 79/79 - 1s - loss: 0.0029 - val_loss: 0.0049 - 1s/epoch - 13ms/step
# Epoch 17/50
# 79/79 - 1s - loss: 0.0028 - val_loss: 0.0065 - 1s/epoch - 13ms/step
# Epoch 18/50
# 79/79 - 1s - loss: 0.0027 - val_loss: 0.0053 - 1s/epoch - 13ms/step
# Epoch 19/50
# 79/79 - 1s - loss: 0.0028 - val_loss: 0.0066 - 1s/epoch - 13ms/step
# Epoch 20/50
# 79/79 - 1s - loss: 0.0026 - val_loss: 0.0074 - 1s/epoch - 13ms/step
# Epoch 21/50
# 79/79 - 1s - loss: 0.0027 - val_loss: 0.0072 - 1s/epoch - 13ms/step
# Total execution time: 25.442342281341553
# 79/79 [==============================] - 1s 5ms/step
# 10/10 [==============================] - 0s 5ms/step
# 9/9 [==============================] - 0s 5ms/step
# Epoch 1/50
# 79/79 - 3s - loss: 0.0734 - val_loss: 0.0276 - 3s/epoch - 38ms/step
# Epoch 2/50
# 79/79 - 1s - loss: 0.0338 - val_loss: 0.0203 - 552ms/epoch - 7ms/step
# Epoch 3/50
# 79/79 - 1s - loss: 0.0084 - val_loss: 0.0115 - 554ms/epoch - 7ms/step
# Epoch 4/50
# 79/79 - 1s - loss: 0.0056 - val_loss: 0.0113 - 563ms/epoch - 7ms/step
# Epoch 5/50
# 79/79 - 1s - loss: 0.0056 - val_loss: 0.0126 - 570ms/epoch - 7ms/step
# Epoch 6/50
# 79/79 - 1s - loss: 0.0047 - val_loss: 0.0113 - 557ms/epoch - 7ms/step
# Epoch 7/50
# 79/79 - 1s - loss: 0.0062 - val_loss: 0.0156 - 538ms/epoch - 7ms/step
# Epoch 8/50
# 79/79 - 0s - loss: 0.0053 - val_loss: 0.0123 - 416ms/epoch - 5ms/step
# Epoch 9/50
# 79/79 - 0s - loss: 0.0076 - val_loss: 0.0194 - 408ms/epoch - 5ms/step
# Epoch 10/50
# 79/79 - 0s - loss: 0.0060 - val_loss: 0.0098 - 412ms/epoch - 5ms/step
# Epoch 11/50
# 79/79 - 0s - loss: 0.0076 - val_loss: 0.0151 - 431ms/epoch - 5ms/step
# Epoch 12/50
# 79/79 - 0s - loss: 0.0058 - val_loss: 0.0086 - 423ms/epoch - 5ms/step
# Epoch 13/50
# 79/79 - 0s - loss: 0.0067 - val_loss: 0.0101 - 425ms/epoch - 5ms/step
# Epoch 14/50
# 79/79 - 0s - loss: 0.0048 - val_loss: 0.0081 - 408ms/epoch - 5ms/step
# Epoch 15/50
# 79/79 - 0s - loss: 0.0055 - val_loss: 0.0085 - 418ms/epoch - 5ms/step
# Epoch 16/50
# 79/79 - 0s - loss: 0.0040 - val_loss: 0.0077 - 450ms/epoch - 6ms/step
# Epoch 17/50
# 79/79 - 0s - loss: 0.0046 - val_loss: 0.0081 - 411ms/epoch - 5ms/step
# Epoch 18/50
# 79/79 - 1s - loss: 0.0036 - val_loss: 0.0075 - 836ms/epoch - 11ms/step
# Epoch 19/50
# 79/79 - 0s - loss: 0.0041 - val_loss: 0.0082 - 490ms/epoch - 6ms/step
# Epoch 20/50
# 79/79 - 0s - loss: 0.0034 - val_loss: 0.0074 - 414ms/epoch - 5ms/step
# Epoch 21/50
# 79/79 - 0s - loss: 0.0039 - val_loss: 0.0085 - 449ms/epoch - 6ms/step
# Epoch 22/50
# 79/79 - 0s - loss: 0.0033 - val_loss: 0.0074 - 416ms/epoch - 5ms/step
# Epoch 23/50
# 79/79 - 0s - loss: 0.0038 - val_loss: 0.0088 - 442ms/epoch - 6ms/step
# Epoch 24/50
# 79/79 - 0s - loss: 0.0032 - val_loss: 0.0075 - 419ms/epoch - 5ms/step
# Epoch 25/50
# 79/79 - 0s - loss: 0.0036 - val_loss: 0.0089 - 411ms/epoch - 5ms/step
# Epoch 26/50
# 79/79 - 0s - loss: 0.0031 - val_loss: 0.0074 - 457ms/epoch - 6ms/step
# Epoch 27/50
# 79/79 - 0s - loss: 0.0034 - val_loss: 0.0085 - 459ms/epoch - 6ms/step
# Total execution time: 15.48662781715393
# 79/79 [==============================] - 1s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 9/9 [==============================] - 0s 3ms/step
# Epoch 1/50
# 79/79 - 3s - loss: 0.0452 - val_loss: 0.0168 - 3s/epoch - 36ms/step
# Epoch 2/50
# 79/79 - 1s - loss: 0.0096 - val_loss: 0.0154 - 636ms/epoch - 8ms/step
# Epoch 3/50
# 79/79 - 1s - loss: 0.0075 - val_loss: 0.0124 - 642ms/epoch - 8ms/step
# Epoch 4/50
# 79/79 - 1s - loss: 0.0064 - val_loss: 0.0117 - 634ms/epoch - 8ms/step
# Epoch 5/50
# 79/79 - 1s - loss: 0.0057 - val_loss: 0.0113 - 647ms/epoch - 8ms/step
# Epoch 6/50
# 79/79 - 1s - loss: 0.0052 - val_loss: 0.0106 - 686ms/epoch - 9ms/step
# Epoch 7/50
# 79/79 - 1s - loss: 0.0047 - val_loss: 0.0099 - 738ms/epoch - 9ms/step
# Epoch 8/50
# 79/79 - 1s - loss: 0.0044 - val_loss: 0.0092 - 742ms/epoch - 9ms/step
# Epoch 9/50
# 79/79 - 1s - loss: 0.0041 - val_loss: 0.0086 - 723ms/epoch - 9ms/step
# Epoch 10/50
# 79/79 - 1s - loss: 0.0038 - val_loss: 0.0080 - 726ms/epoch - 9ms/step
# Epoch 11/50
# 79/79 - 1s - loss: 0.0036 - val_loss: 0.0076 - 748ms/epoch - 9ms/step
# Epoch 12/50
# 79/79 - 1s - loss: 0.0034 - val_loss: 0.0080 - 695ms/epoch - 9ms/step
# Epoch 13/50
# 79/79 - 1s - loss: 0.0033 - val_loss: 0.0128 - 637ms/epoch - 8ms/step
# Epoch 14/50
# 79/79 - 1s - loss: 0.0037 - val_loss: 0.0117 - 644ms/epoch - 8ms/step
# Epoch 15/50
# 79/79 - 1s - loss: 0.0051 - val_loss: 0.0257 - 641ms/epoch - 8ms/step
# Epoch 16/50
# 79/79 - 1s - loss: 0.0045 - val_loss: 0.0061 - 658ms/epoch - 8ms/step
# Epoch 17/50
# 79/79 - 1s - loss: 0.0033 - val_loss: 0.0061 - 644ms/epoch - 8ms/step
# Epoch 18/50
# 79/79 - 1s - loss: 0.0029 - val_loss: 0.0058 - 642ms/epoch - 8ms/step
# Epoch 19/50
# 79/79 - 1s - loss: 0.0029 - val_loss: 0.0057 - 632ms/epoch - 8ms/step
# Epoch 20/50
# 79/79 - 1s - loss: 0.0028 - val_loss: 0.0055 - 653ms/epoch - 8ms/step
# Epoch 21/50
# 79/79 - 1s - loss: 0.0027 - val_loss: 0.0054 - 657ms/epoch - 8ms/step
# Epoch 22/50
# 79/79 - 1s - loss: 0.0026 - val_loss: 0.0054 - 641ms/epoch - 8ms/step
# Epoch 23/50
# 79/79 - 1s - loss: 0.0026 - val_loss: 0.0054 - 637ms/epoch - 8ms/step
# Epoch 24/50
# 79/79 - 1s - loss: 0.0026 - val_loss: 0.0055 - 639ms/epoch - 8ms/step
# Epoch 25/50
# 79/79 - 1s - loss: 0.0026 - val_loss: 0.0057 - 643ms/epoch - 8ms/step
# Epoch 26/50
# 79/79 - 1s - loss: 0.0026 - val_loss: 0.0054 - 641ms/epoch - 8ms/step
# Epoch 27/50
# 79/79 - 1s - loss: 0.0025 - val_loss: 0.0055 - 667ms/epoch - 8ms/step
# Epoch 28/50
# 79/79 - 1s - loss: 0.0024 - val_loss: 0.0055 - 716ms/epoch - 9ms/step
# Epoch 29/50
# 79/79 - 1s - loss: 0.0024 - val_loss: 0.0054 - 742ms/epoch - 9ms/step
# Epoch 30/50
# 79/79 - 1s - loss: 0.0024 - val_loss: 0.0053 - 751ms/epoch - 10ms/step
# Epoch 31/50
# 79/79 - 1s - loss: 0.0023 - val_loss: 0.0056 - 759ms/epoch - 10ms/step
# Epoch 32/50
# 79/79 - 1s - loss: 0.0024 - val_loss: 0.0048 - 742ms/epoch - 9ms/step
# Epoch 33/50
# 79/79 - 1s - loss: 0.0022 - val_loss: 0.0052 - 736ms/epoch - 9ms/step
# Epoch 34/50
# 79/79 - 1s - loss: 0.0024 - val_loss: 0.0075 - 635ms/epoch - 8ms/step
# Epoch 35/50
# 79/79 - 1s - loss: 0.0021 - val_loss: 0.0043 - 640ms/epoch - 8ms/step
# Epoch 36/50
# 79/79 - 1s - loss: 0.0023 - val_loss: 0.0043 - 639ms/epoch - 8ms/step
# Epoch 37/50
# 79/79 - 1s - loss: 0.0021 - val_loss: 0.0042 - 663ms/epoch - 8ms/step
# Epoch 38/50
# 79/79 - 1s - loss: 0.0020 - val_loss: 0.0042 - 667ms/epoch - 8ms/step
# Epoch 39/50
# 79/79 - 1s - loss: 0.0019 - val_loss: 0.0043 - 628ms/epoch - 8ms/step
# Epoch 40/50
# 79/79 - 1s - loss: 0.0020 - val_loss: 0.0043 - 637ms/epoch - 8ms/step
# Epoch 41/50
# 79/79 - 1s - loss: 0.0019 - val_loss: 0.0042 - 636ms/epoch - 8ms/step
# Epoch 42/50
# 79/79 - 1s - loss: 0.0019 - val_loss: 0.0041 - 641ms/epoch - 8ms/step
# Epoch 43/50
# 79/79 - 1s - loss: 0.0019 - val_loss: 0.0041 - 638ms/epoch - 8ms/step
# Epoch 44/50
# 79/79 - 1s - loss: 0.0018 - val_loss: 0.0041 - 647ms/epoch - 8ms/step
# Epoch 45/50
# 79/79 - 1s - loss: 0.0018 - val_loss: 0.0042 - 652ms/epoch - 8ms/step
# Epoch 46/50
# 79/79 - 1s - loss: 0.0018 - val_loss: 0.0047 - 663ms/epoch - 8ms/step
# Epoch 47/50
# 79/79 - 1s - loss: 0.0019 - val_loss: 0.0045 - 642ms/epoch - 8ms/step
# Epoch 48/50
# 79/79 - 1s - loss: 0.0017 - val_loss: 0.0042 - 654ms/epoch - 8ms/step
# Epoch 49/50
# 79/79 - 1s - loss: 0.0018 - val_loss: 0.0043 - 736ms/epoch - 9ms/step
# Total execution time: 35.2322313785553
# 79/79 [==============================] - 1s 5ms/step
# 10/10 [==============================] - 0s 4ms/step
# 9/9 [==============================] - 0s 4ms/step
# Epoch 1/50
# 79/79 - 3s - loss: 0.0356 - val_loss: 0.0386 - 3s/epoch - 42ms/step
# Epoch 2/50
# 79/79 - 1s - loss: 0.0091 - val_loss: 0.0304 - 1s/epoch - 14ms/step
# Epoch 3/50
# 79/79 - 1s - loss: 0.0065 - val_loss: 0.0110 - 1s/epoch - 15ms/step
# Epoch 4/50
# 79/79 - 1s - loss: 0.0049 - val_loss: 0.0105 - 1s/epoch - 14ms/step
# Epoch 5/50
# 79/79 - 1s - loss: 0.0046 - val_loss: 0.0094 - 1s/epoch - 14ms/step
# Epoch 6/50
# 79/79 - 1s - loss: 0.0043 - val_loss: 0.0098 - 1s/epoch - 13ms/step
# Epoch 7/50
# 79/79 - 1s - loss: 0.0040 - val_loss: 0.0117 - 1s/epoch - 13ms/step
# Epoch 8/50
# 79/79 - 1s - loss: 0.0039 - val_loss: 0.0202 - 1s/epoch - 13ms/step
# Epoch 9/50
# 79/79 - 1s - loss: 0.0046 - val_loss: 0.0081 - 1s/epoch - 13ms/step
# Epoch 10/50
# 79/79 - 1s - loss: 0.0056 - val_loss: 0.0253 - 1s/epoch - 13ms/step
# Epoch 11/50
# 79/79 - 1s - loss: 0.0059 - val_loss: 0.0079 - 1s/epoch - 13ms/step
# Epoch 12/50
# 79/79 - 1s - loss: 0.0043 - val_loss: 0.0065 - 1s/epoch - 13ms/step
# Epoch 13/50
# 79/79 - 1s - loss: 0.0031 - val_loss: 0.0064 - 1s/epoch - 13ms/step
# Epoch 14/50
# 79/79 - 1s - loss: 0.0030 - val_loss: 0.0062 - 1s/epoch - 13ms/step
# Epoch 15/50
# 79/79 - 1s - loss: 0.0029 - val_loss: 0.0058 - 1s/epoch - 13ms/step
# Epoch 16/50
# 79/79 - 1s - loss: 0.0028 - val_loss: 0.0055 - 1s/epoch - 15ms/step
# Epoch 17/50
# 79/79 - 1s - loss: 0.0027 - val_loss: 0.0053 - 1s/epoch - 14ms/step
# Epoch 18/50
# 79/79 - 1s - loss: 0.0026 - val_loss: 0.0052 - 1s/epoch - 14ms/step
# Epoch 19/50
# 79/79 - 1s - loss: 0.0026 - val_loss: 0.0051 - 1s/epoch - 14ms/step
# Epoch 20/50
# 79/79 - 1s - loss: 0.0025 - val_loss: 0.0051 - 1s/epoch - 13ms/step
# Epoch 21/50
# 79/79 - 1s - loss: 0.0025 - val_loss: 0.0051 - 1s/epoch - 13ms/step
# Epoch 22/50
# 79/79 - 1s - loss: 0.0025 - val_loss: 0.0051 - 1s/epoch - 13ms/step
# Epoch 23/50
# 79/79 - 1s - loss: 0.0025 - val_loss: 0.0052 - 1s/epoch - 13ms/step
# Epoch 24/50
# 79/79 - 1s - loss: 0.0025 - val_loss: 0.0052 - 1s/epoch - 13ms/step
# Epoch 25/50
# 79/79 - 1s - loss: 0.0024 - val_loss: 0.0051 - 1s/epoch - 13ms/step
# Epoch 26/50
# 79/79 - 1s - loss: 0.0024 - val_loss: 0.0051 - 1s/epoch - 13ms/step
# Epoch 27/50
# 79/79 - 1s - loss: 0.0023 - val_loss: 0.0050 - 1s/epoch - 13ms/step
# Epoch 28/50
# 79/79 - 1s - loss: 0.0023 - val_loss: 0.0047 - 1s/epoch - 13ms/step
# Epoch 29/50
# 79/79 - 1s - loss: 0.0022 - val_loss: 0.0044 - 1s/epoch - 15ms/step
# Epoch 30/50
# 79/79 - 1s - loss: 0.0024 - val_loss: 0.0056 - 1s/epoch - 15ms/step
# Epoch 31/50
# 79/79 - 1s - loss: 0.0022 - val_loss: 0.0054 - 1s/epoch - 15ms/step
# Epoch 32/50
# 79/79 - 1s - loss: 0.0022 - val_loss: 0.0049 - 1s/epoch - 15ms/step
# Epoch 33/50
# 79/79 - 1s - loss: 0.0024 - val_loss: 0.0041 - 1s/epoch - 13ms/step
# Epoch 34/50
# 79/79 - 1s - loss: 0.0026 - val_loss: 0.0070 - 1s/epoch - 13ms/step
# Epoch 35/50
# 79/79 - 1s - loss: 0.0021 - val_loss: 0.0040 - 1s/epoch - 13ms/step
# Epoch 36/50
# 79/79 - 1s - loss: 0.0020 - val_loss: 0.0041 - 1s/epoch - 13ms/step
# Epoch 37/50
# 79/79 - 1s - loss: 0.0020 - val_loss: 0.0042 - 1s/epoch - 13ms/step
# Epoch 38/50
# 79/79 - 1s - loss: 0.0019 - val_loss: 0.0043 - 1s/epoch - 13ms/step
# Epoch 39/50
# 79/79 - 1s - loss: 0.0019 - val_loss: 0.0048 - 1s/epoch - 13ms/step
# Epoch 40/50
# 79/79 - 1s - loss: 0.0019 - val_loss: 0.0052 - 1s/epoch - 13ms/step
# Epoch 41/50
# 79/79 - 1s - loss: 0.0019 - val_loss: 0.0051 - 1s/epoch - 13ms/step
# Epoch 42/50
# 79/79 - 1s - loss: 0.0019 - val_loss: 0.0047 - 1s/epoch - 13ms/step
# Total execution time: 46.887431144714355
# 79/79 [==============================] - 1s 7ms/step
# 10/10 [==============================] - 0s 5ms/step
# 9/9 [==============================] - 0s 5ms/step
# Epoch 1/50
# 79/79 - 4s - loss: 0.0851 - val_loss: 1.0953 - 4s/epoch - 54ms/step
# Epoch 2/50
# 79/79 - 0s - loss: 0.0332 - val_loss: 0.2410 - 447ms/epoch - 6ms/step
# Epoch 3/50
# 79/79 - 0s - loss: 0.0168 - val_loss: 0.0603 - 416ms/epoch - 5ms/step
# Epoch 4/50
# 79/79 - 0s - loss: 0.0287 - val_loss: 0.0462 - 436ms/epoch - 6ms/step
# Epoch 5/50
# 79/79 - 0s - loss: 0.0381 - val_loss: 0.1525 - 456ms/epoch - 6ms/step
# Epoch 6/50
# 79/79 - 0s - loss: 0.0312 - val_loss: 0.1856 - 424ms/epoch - 5ms/step
# Epoch 7/50
# 79/79 - 0s - loss: 0.0164 - val_loss: 0.0945 - 426ms/epoch - 5ms/step
# Epoch 8/50
# 79/79 - 0s - loss: 0.0096 - val_loss: 0.0466 - 419ms/epoch - 5ms/step
# Epoch 9/50
# 79/79 - 0s - loss: 0.0081 - val_loss: 0.0330 - 435ms/epoch - 6ms/step
# Epoch 10/50
# 79/79 - 0s - loss: 0.0077 - val_loss: 0.0289 - 413ms/epoch - 5ms/step
# Epoch 11/50
# 79/79 - 0s - loss: 0.0075 - val_loss: 0.0265 - 427ms/epoch - 5ms/step
# Epoch 12/50
# 79/79 - 0s - loss: 0.0074 - val_loss: 0.0244 - 416ms/epoch - 5ms/step
# Epoch 13/50
# 79/79 - 0s - loss: 0.0073 - val_loss: 0.0224 - 451ms/epoch - 6ms/step
# Epoch 14/50
# 79/79 - 0s - loss: 0.0073 - val_loss: 0.0205 - 467ms/epoch - 6ms/step
# Epoch 15/50
# 79/79 - 0s - loss: 0.0074 - val_loss: 0.0189 - 449ms/epoch - 6ms/step
# Epoch 16/50
# 79/79 - 0s - loss: 0.0074 - val_loss: 0.0176 - 419ms/epoch - 5ms/step
# Epoch 17/50
# 79/79 - 0s - loss: 0.0074 - val_loss: 0.0165 - 414ms/epoch - 5ms/step
# Epoch 18/50
# 79/79 - 0s - loss: 0.0075 - val_loss: 0.0157 - 453ms/epoch - 6ms/step
# Epoch 19/50
# 79/79 - 0s - loss: 0.0075 - val_loss: 0.0151 - 412ms/epoch - 5ms/step
# Epoch 20/50
# 79/79 - 0s - loss: 0.0074 - val_loss: 0.0146 - 429ms/epoch - 5ms/step
# Epoch 21/50
# 79/79 - 0s - loss: 0.0074 - val_loss: 0.0141 - 419ms/epoch - 5ms/step
# Epoch 22/50
# 79/79 - 0s - loss: 0.0073 - val_loss: 0.0138 - 419ms/epoch - 5ms/step
# Epoch 23/50
# 79/79 - 0s - loss: 0.0071 - val_loss: 0.0134 - 436ms/epoch - 6ms/step
# Epoch 24/50
# 79/79 - 0s - loss: 0.0070 - val_loss: 0.0131 - 491ms/epoch - 6ms/step
# Epoch 25/50
# 79/79 - 1s - loss: 0.0068 - val_loss: 0.0129 - 548ms/epoch - 7ms/step
# Epoch 26/50
# 79/79 - 1s - loss: 0.0066 - val_loss: 0.0126 - 530ms/epoch - 7ms/step
# Epoch 27/50
# 79/79 - 1s - loss: 0.0065 - val_loss: 0.0124 - 570ms/epoch - 7ms/step
# Epoch 28/50
# 79/79 - 1s - loss: 0.0063 - val_loss: 0.0122 - 528ms/epoch - 7ms/step
# Epoch 29/50
# 79/79 - 1s - loss: 0.0062 - val_loss: 0.0121 - 585ms/epoch - 7ms/step
# Epoch 30/50
# 79/79 - 1s - loss: 0.0061 - val_loss: 0.0119 - 541ms/epoch - 7ms/step
# Epoch 31/50
# 79/79 - 1s - loss: 0.0060 - val_loss: 0.0118 - 547ms/epoch - 7ms/step
# Epoch 32/50
# 79/79 - 0s - loss: 0.0059 - val_loss: 0.0117 - 485ms/epoch - 6ms/step
# Epoch 33/50
# 79/79 - 0s - loss: 0.0058 - val_loss: 0.0115 - 423ms/epoch - 5ms/step
# Epoch 34/50
# 79/79 - 0s - loss: 0.0057 - val_loss: 0.0114 - 454ms/epoch - 6ms/step
# Epoch 35/50
# 79/79 - 0s - loss: 0.0057 - val_loss: 0.0113 - 419ms/epoch - 5ms/step
# Epoch 36/50
# 79/79 - 0s - loss: 0.0056 - val_loss: 0.0112 - 421ms/epoch - 5ms/step
# Epoch 37/50
# 79/79 - 0s - loss: 0.0056 - val_loss: 0.0111 - 423ms/epoch - 5ms/step
# Epoch 38/50
# 79/79 - 0s - loss: 0.0055 - val_loss: 0.0110 - 460ms/epoch - 6ms/step
# Epoch 39/50
# 79/79 - 0s - loss: 0.0055 - val_loss: 0.0109 - 415ms/epoch - 5ms/step
# Epoch 40/50
# 79/79 - 0s - loss: 0.0054 - val_loss: 0.0108 - 424ms/epoch - 5ms/step
# Epoch 41/50
# 79/79 - 0s - loss: 0.0054 - val_loss: 0.0107 - 428ms/epoch - 5ms/step
# Epoch 42/50
# 79/79 - 0s - loss: 0.0053 - val_loss: 0.0106 - 463ms/epoch - 6ms/step
# Epoch 43/50
# 79/79 - 0s - loss: 0.0052 - val_loss: 0.0105 - 449ms/epoch - 6ms/step
# Epoch 44/50
# 79/79 - 0s - loss: 0.0052 - val_loss: 0.0104 - 423ms/epoch - 5ms/step
# Epoch 45/50
# 79/79 - 0s - loss: 0.0051 - val_loss: 0.0103 - 428ms/epoch - 5ms/step
# Epoch 46/50
# 79/79 - 0s - loss: 0.0050 - val_loss: 0.0102 - 426ms/epoch - 5ms/step
# Epoch 47/50
# 79/79 - 0s - loss: 0.0050 - val_loss: 0.0102 - 424ms/epoch - 5ms/step
# Epoch 48/50
# 79/79 - 0s - loss: 0.0049 - val_loss: 0.0101 - 423ms/epoch - 5ms/step
# Epoch 49/50
# 79/79 - 0s - loss: 0.0048 - val_loss: 0.0100 - 432ms/epoch - 5ms/step
# Epoch 50/50
# 79/79 - 0s - loss: 0.0048 - val_loss: 0.0099 - 422ms/epoch - 5ms/step
# Total execution time: 43.54303598403931
# 79/79 [==============================] - 1s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 9/9 [==============================] - 0s 3ms/step
# Epoch 1/50
# 79/79 - 3s - loss: 0.0627 - val_loss: 0.3520 - 3s/epoch - 36ms/step
# Epoch 2/50
# 79/79 - 1s - loss: 0.0210 - val_loss: 0.0286 - 648ms/epoch - 8ms/step
# Epoch 3/50
# 79/79 - 1s - loss: 0.0130 - val_loss: 0.0262 - 646ms/epoch - 8ms/step
# Epoch 4/50
# 79/79 - 1s - loss: 0.0139 - val_loss: 0.0381 - 645ms/epoch - 8ms/step
# Epoch 5/50
# 79/79 - 1s - loss: 0.0159 - val_loss: 0.0362 - 639ms/epoch - 8ms/step
# Epoch 6/50
# 79/79 - 1s - loss: 0.0179 - val_loss: 0.0328 - 638ms/epoch - 8ms/step
# Epoch 7/50
# 79/79 - 1s - loss: 0.0180 - val_loss: 0.0311 - 664ms/epoch - 8ms/step
# Epoch 8/50
# 79/79 - 1s - loss: 0.0179 - val_loss: 0.0142 - 676ms/epoch - 9ms/step
# Epoch 9/50
# 79/79 - 1s - loss: 0.0171 - val_loss: 0.0174 - 666ms/epoch - 8ms/step
# Epoch 10/50
# 79/79 - 1s - loss: 0.0153 - val_loss: 0.0243 - 681ms/epoch - 9ms/step
# Epoch 11/50
# 79/79 - 1s - loss: 0.0121 - val_loss: 0.0231 - 744ms/epoch - 9ms/step
# Epoch 12/50
# 79/79 - 1s - loss: 0.0092 - val_loss: 0.0186 - 741ms/epoch - 9ms/step
# Epoch 13/50
# 79/79 - 1s - loss: 0.0073 - val_loss: 0.0147 - 747ms/epoch - 9ms/step
# Epoch 14/50
# 79/79 - 1s - loss: 0.0063 - val_loss: 0.0132 - 746ms/epoch - 9ms/step
# Epoch 15/50
# 79/79 - 1s - loss: 0.0059 - val_loss: 0.0127 - 725ms/epoch - 9ms/step
# Epoch 16/50
# 79/79 - 1s - loss: 0.0056 - val_loss: 0.0124 - 690ms/epoch - 9ms/step
# Epoch 17/50
# 79/79 - 1s - loss: 0.0054 - val_loss: 0.0122 - 645ms/epoch - 8ms/step
# Epoch 18/50
# 79/79 - 1s - loss: 0.0053 - val_loss: 0.0119 - 663ms/epoch - 8ms/step
# Epoch 19/50
# 79/79 - 1s - loss: 0.0053 - val_loss: 0.0117 - 667ms/epoch - 8ms/step
# Epoch 20/50
# 79/79 - 1s - loss: 0.0053 - val_loss: 0.0116 - 664ms/epoch - 8ms/step
# Epoch 21/50
# 79/79 - 1s - loss: 0.0053 - val_loss: 0.0114 - 643ms/epoch - 8ms/step
# Epoch 22/50
# 79/79 - 1s - loss: 0.0054 - val_loss: 0.0113 - 643ms/epoch - 8ms/step
# Epoch 23/50
# 79/79 - 1s - loss: 0.0055 - val_loss: 0.0112 - 665ms/epoch - 8ms/step
# Epoch 24/50
# 79/79 - 1s - loss: 0.0057 - val_loss: 0.0112 - 647ms/epoch - 8ms/step
# Epoch 25/50
# 79/79 - 1s - loss: 0.0059 - val_loss: 0.0112 - 663ms/epoch - 8ms/step
# Epoch 26/50
# 79/79 - 1s - loss: 0.0061 - val_loss: 0.0112 - 653ms/epoch - 8ms/step
# Epoch 27/50
# 79/79 - 1s - loss: 0.0062 - val_loss: 0.0111 - 670ms/epoch - 8ms/step
# Epoch 28/50
# 79/79 - 1s - loss: 0.0064 - val_loss: 0.0111 - 644ms/epoch - 8ms/step
# Epoch 29/50
# 79/79 - 1s - loss: 0.0065 - val_loss: 0.0110 - 673ms/epoch - 9ms/step
# Epoch 30/50
# 79/79 - 1s - loss: 0.0066 - val_loss: 0.0109 - 642ms/epoch - 8ms/step
# Epoch 31/50
# 79/79 - 1s - loss: 0.0066 - val_loss: 0.0108 - 681ms/epoch - 9ms/step
# Epoch 32/50
# 79/79 - 1s - loss: 0.0066 - val_loss: 0.0106 - 735ms/epoch - 9ms/step
# Epoch 33/50
# 79/79 - 1s - loss: 0.0065 - val_loss: 0.0105 - 719ms/epoch - 9ms/step
# Epoch 34/50
# 79/79 - 1s - loss: 0.0063 - val_loss: 0.0104 - 741ms/epoch - 9ms/step
# Epoch 35/50
# 79/79 - 1s - loss: 0.0061 - val_loss: 0.0103 - 738ms/epoch - 9ms/step
# Epoch 36/50
# 79/79 - 1s - loss: 0.0059 - val_loss: 0.0102 - 1s/epoch - 13ms/step
# Epoch 37/50
# 79/79 - 1s - loss: 0.0057 - val_loss: 0.0102 - 965ms/epoch - 12ms/step
# Epoch 38/50
# 79/79 - 1s - loss: 0.0055 - val_loss: 0.0102 - 640ms/epoch - 8ms/step
# Epoch 39/50
# 79/79 - 1s - loss: 0.0052 - val_loss: 0.0108 - 635ms/epoch - 8ms/step
# Epoch 40/50
# 79/79 - 1s - loss: 0.0050 - val_loss: 0.0110 - 662ms/epoch - 8ms/step
# Epoch 41/50
# 79/79 - 1s - loss: 0.0048 - val_loss: 0.0114 - 649ms/epoch - 8ms/step
# Epoch 42/50
# 79/79 - 1s - loss: 0.0047 - val_loss: 0.0107 - 642ms/epoch - 8ms/step
# Epoch 43/50
# 79/79 - 1s - loss: 0.0047 - val_loss: 0.0109 - 669ms/epoch - 8ms/step
# Epoch 44/50
# 79/79 - 1s - loss: 0.0046 - val_loss: 0.0104 - 640ms/epoch - 8ms/step
# Total execution time: 32.74952483177185
# 79/79 [==============================] - 1s 4ms/step
# 10/10 [==============================] - 0s 4ms/step
# 9/9 [==============================] - 0s 3ms/step
# Epoch 1/50
# 79/79 - 3s - loss: 0.0941 - val_loss: 0.1625 - 3s/epoch - 41ms/step
# Epoch 2/50
# 79/79 - 1s - loss: 0.0275 - val_loss: 0.0559 - 1s/epoch - 13ms/step
# Epoch 3/50
# 79/79 - 1s - loss: 0.0125 - val_loss: 0.0223 - 1s/epoch - 13ms/step
# Epoch 4/50
# 79/79 - 1s - loss: 0.0109 - val_loss: 0.0463 - 1s/epoch - 14ms/step
# Epoch 5/50
# 79/79 - 1s - loss: 0.0118 - val_loss: 0.0548 - 1s/epoch - 15ms/step
# Epoch 6/50
# 79/79 - 1s - loss: 0.0117 - val_loss: 0.0540 - 1s/epoch - 14ms/step
# Epoch 7/50
# 79/79 - 1s - loss: 0.0119 - val_loss: 0.0548 - 1s/epoch - 15ms/step
# Epoch 8/50
# 79/79 - 1s - loss: 0.0124 - val_loss: 0.0539 - 1s/epoch - 13ms/step
# Epoch 9/50
# 79/79 - 1s - loss: 0.0129 - val_loss: 0.0507 - 1s/epoch - 13ms/step
# Epoch 10/50
# 79/79 - 1s - loss: 0.0131 - val_loss: 0.0501 - 1s/epoch - 13ms/step
# Total execution time: 13.04796838760376
# 79/79 [==============================] - 1s 7ms/step
# 10/10 [==============================] - 0s 5ms/step
# 9/9 [==============================] - 0s 5ms/step
#    Learning Rate  Hidden Neurons  Test RMSE   Val RMSE  Train RMSE
# 0         0.0010             300  13.893261   9.210473    7.063342
# 1         0.0010             500  35.504868  10.261511    8.783266
# 2         0.0010             700   8.768081   8.873355    7.913935
# 3         0.0005             300  21.976635  11.065306    8.161837
# 4         0.0005             500  17.982827   8.270158    6.515941
# 5         0.0005             700  14.524790   8.205406    6.469675
# 6         0.0001             300  12.407416  12.839340    9.389717
# 7         0.0001             500  15.044828  13.020388   10.200933
# 8         0.0001             700  39.737994  19.277935   12.797587

# %%
print(df_results_lstm)
# Out:
#    Learning Rate  Hidden Neurons  Test RMSE   Val RMSE  Train RMSE
# 0         0.0010             300  13.893261   9.210473    7.063342
# 1         0.0010             500  35.504868  10.261511    8.783266
# 2         0.0010             700   8.768081   8.873355    7.913935
# 3         0.0005             300  21.976635  11.065306    8.161837
# 4         0.0005             500  17.982827   8.270158    6.515941
# 5         0.0005             700  14.524790   8.205406    6.469675
# 6         0.0001             300  12.407416  12.839340    9.389717
# 7         0.0001             500  15.044828  13.020388   10.200933
# 8         0.0001             700  39.737994  19.277935   12.797587

# %% [markdown]
# # Long term Predictive power LSTM

# %%
train_rmse = []
val_rmse = []
test_rmse = []

train_mae = []
val_mae = []
test_mae = []

train_times = []

n_lagged = 50
for predict_window in range(1, 32):

    # frame as supervised learning
    reframed = series_to_supervised(df, n_lagged, predict_window)

    # Dropping future variables
    # At time "t", we only have Open(t) and want to predict Close(t), so we can drop High(t), Volume(t) and Low(t)
    # Also we will drop Open(t-1) because each time step needs to have exactly 4 variables. If we add more time steps we will have
    # a remaining Variable (Open(t)) to spare, so we will replace Open(t-1) with Open(t) for the first lagged variable.
    reframed.drop(['High(t)', 'Low(t)', 'Volume(t)', 'Open(t-'+str(n_lagged)+')'], axis=1, inplace=True)
    reframed.drop(['High(t+'+str(i)+')' for i in range(1, predict_window)], axis=1, inplace=True)
    reframed.drop(['Low(t+'+str(i)+')' for i in range(1, predict_window)], axis=1, inplace=True)
    reframed.drop(['Open(t+'+str(i)+')' for i in range(1, predict_window)], axis=1, inplace=True)
    reframed.drop(['Volume(t+'+str(i)+')' for i in range(1, predict_window)], axis=1, inplace=True)


    # Data splitting
    train_X, train_y = reframed.iloc[:train_samples, :-predict_window].values, reframed.iloc[:train_samples, -predict_window:].values
    val_X, val_y = reframed.iloc[train_samples:val_samples, :-predict_window].values, reframed.iloc[train_samples:val_samples, -predict_window:].values
    test_X, test_y = reframed.iloc[val_samples:, :-predict_window].values, reframed.iloc[val_samples:, -predict_window:].values

    # Reshaping for LSTM
    train_X = train_X.reshape((train_X.shape[0], n_lagged, input_vars))
    val_X = val_X.reshape((val_X.shape[0], n_lagged, input_vars))
    test_X = test_X.reshape((test_X.shape[0], n_lagged, input_vars))

    # Defining model for LSTM
    optimizer = Adam(learning_rate=learning_rate)
    model = Sequential()
    model.add(LSTM(hidden_layer_neurons, input_shape=(train_X.shape[1], train_X.shape[2])))
    model.add(Dense(predict_window)) # Output layer
    model.compile(loss='mse', optimizer=optimizer)

    # Fit network
    t0 = time.time()
    model.fit(train_X, train_y, epochs=epochs, batch_size=batch_size,
                        validation_data=(val_X, val_y), shuffle=False,
                       callbacks = [early_stopping])
    t1 = time.time()

    train_times.append(t1-t0)

    # Predictions
    yhat_train = model.predict(train_X)*std + mean
    yhat_val = model.predict(val_X)*std + mean
    yhat_test = model.predict(test_X)*std + mean

    train_rmse.append(np.mean([np.sqrt(mean_squared_error(y_real*std + mean, y_pred)) for y_real, y_pred in zip(train_y, yhat_train)]))
    val_rmse.append(np.mean([np.sqrt(mean_squared_error(y_real*std + mean, y_pred)) for y_real, y_pred in zip(val_y, yhat_val)]))
    test_rmse.append(np.mean([np.sqrt(mean_squared_error(y_real*std + mean, y_pred)) for y_real, y_pred in zip(test_y, yhat_test)]))

    train_mae.append(np.mean([mean_absolute_error(y_real*std + mean, y_pred) for y_real, y_pred in zip(train_y, yhat_train)]))
    val_mae.append(np.mean([mean_absolute_error(y_real*std + mean, y_pred) for y_real, y_pred in zip(val_y, yhat_val)]))
    test_mae.append(np.mean([mean_absolute_error(y_real*std + mean, y_pred) for y_real, y_pred in zip(test_y, yhat_test)]))
# Out:
# Epoch 1/100
# 79/79 [==============================] - 5s 27ms/step - loss: 0.0428 - val_loss: 0.0216
# Epoch 2/100
# 79/79 [==============================] - 1s 16ms/step - loss: 0.0090 - val_loss: 0.0127
# Epoch 3/100
# 79/79 [==============================] - 1s 18ms/step - loss: 0.0074 - val_loss: 0.0120
# Epoch 4/100
# 79/79 [==============================] - 1s 12ms/step - loss: 0.0063 - val_loss: 0.0111
# Epoch 5/100
# 79/79 [==============================] - 1s 12ms/step - loss: 0.0054 - val_loss: 0.0100
# Epoch 6/100
# 79/79 [==============================] - 1s 12ms/step - loss: 0.0048 - val_loss: 0.0093
# Epoch 7/100
# 79/79 [==============================] - 1s 11ms/step - loss: 0.0044 - val_loss: 0.0088
# Epoch 8/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0040 - val_loss: 0.0086
# Epoch 9/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0037 - val_loss: 0.0096
# Epoch 10/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0035 - val_loss: 0.0163
# Epoch 11/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0042 - val_loss: 0.0074
# Epoch 12/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0049 - val_loss: 0.0154
# Epoch 13/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0056 - val_loss: 0.0072
# Epoch 14/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0037 - val_loss: 0.0067
# Epoch 15/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0031 - val_loss: 0.0065
# Epoch 16/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.0030 - val_loss: 0.0060
# Epoch 17/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.0030 - val_loss: 0.0059
# Epoch 18/100
# 79/79 [==============================] - 1s 11ms/step - loss: 0.0029 - val_loss: 0.0058
# Epoch 19/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.0029 - val_loss: 0.0058
# Epoch 20/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.0030 - val_loss: 0.0060
# Epoch 21/100
# 79/79 [==============================] - 1s 11ms/step - loss: 0.0030 - val_loss: 0.0065
# Epoch 22/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0031 - val_loss: 0.0073
# Epoch 23/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0032 - val_loss: 0.0085
# Epoch 24/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0034 - val_loss: 0.0096
# Epoch 25/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0034 - val_loss: 0.0057
# Epoch 26/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0034 - val_loss: 0.0077
# Epoch 27/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0035 - val_loss: 0.0083
# Epoch 28/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0037 - val_loss: 0.0080
# Epoch 29/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0040 - val_loss: 0.0052
# Epoch 30/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0040 - val_loss: 0.0046
# Epoch 31/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0040 - val_loss: 0.0096
# Epoch 32/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0035 - val_loss: 0.0167
# Epoch 33/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0030 - val_loss: 0.0075
# Epoch 34/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0036 - val_loss: 0.0041
# Epoch 35/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.0022 - val_loss: 0.0040
# Epoch 36/100
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0020 - val_loss: 0.0039
# Epoch 37/100
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0018 - val_loss: 0.0038
# Epoch 38/100
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0017 - val_loss: 0.0038
# Epoch 39/100
# 79/79 [==============================] - 1s 12ms/step - loss: 0.0017 - val_loss: 0.0038
# Epoch 40/100
# 79/79 [==============================] - 1s 12ms/step - loss: 0.0017 - val_loss: 0.0038
# Epoch 41/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.0017 - val_loss: 0.0039
# Epoch 42/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.0017 - val_loss: 0.0039
# Epoch 43/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0018 - val_loss: 0.0040
# Epoch 44/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0040
# Epoch 45/100
# 79/79 [==============================] - 1s 11ms/step - loss: 0.0018 - val_loss: 0.0041
# Epoch 46/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0042
# Epoch 47/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0043
# Epoch 48/100
# 79/79 [==============================] - 1s 12ms/step - loss: 0.0018 - val_loss: 0.0044
# Epoch 49/100
# 79/79 [==============================] - 1s 12ms/step - loss: 0.0019 - val_loss: 0.0045
# 79/79 [==============================] - 1s 7ms/step
# 10/10 [==============================] - 0s 9ms/step
# 9/9 [==============================] - 0s 9ms/step
# Epoch 1/100
# 79/79 [==============================] - 5s 18ms/step - loss: 0.0605 - val_loss: 0.0671
# Epoch 2/100
# 79/79 [==============================] - 1s 11ms/step - loss: 0.
100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.0466 - val_loss: 0.1918
# Epoch 33/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.0496 - val_loss: 0.0727
# Epoch 34/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0491 - val_loss: 0.1497
# Epoch 35/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0520 - val_loss: 0.1050
# Epoch 36/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.0478 - val_loss: 0.1776
# 79/79 [==============================] - 1s 3ms/step
# 10/10 [==============================] - 0s 4ms/step
# 8/8 [==============================] - 0s 4ms/step

# %%
x_ticks = range(1, 32)
plt.plot(x_ticks, train_rmse, '-o', label='Train')
plt.plot(x_ticks, val_rmse, '-o', label='Validation')
plt.plot(x_ticks, test_rmse, '-o', label='Test')

plt.title("RMSE evolution for different prediction horizon")
plt.xlabel("Prediction Horizon")
plt.ylabel("RMSE")
plt.legend()
plt.show()

# %%
x_ticks = range(1, 32)
plt.plot(x_ticks, train_mae, '-o', label='Train')
plt.plot(x_ticks, val_mae, '-o', label='Validation')
plt.plot(x_ticks, test_mae, '-o', label='Test')

plt.title("MAE evolution for different prediction horizon")
plt.xlabel("Prediction Horizon")
plt.ylabel("MAE")
plt.legend()
plt.show()

# %%
lstm_longterm_rmse = test_rmse
lstm_longterm_mae = test_mae

# %%
x_ticks = range(1, 32)
plt.plot(x_ticks, train_times, '-o')

plt.xlabel("Prediction Horizon")
plt.ylabel("Training times (seconds)")
plt.show()

# %% [markdown]
# # Simple RNN model

# %%
# frame as supervised learning
predict_window = 1
reframed = series_to_supervised(df, n_lagged, predict_window)

# Dropping future variables
# At time "t", we only have Open(t) and want to predict Close(t), so we can drop High(t), Volume(t) and Low(t)
# Also we will drop Open(t-1) because each time step needs to have exactly 4 variables. If we add more time steps we will have
# a remaining Variable (Open(t)) to spare, so we will replace Open(t-1) with Open(t) for the first lagged variable.
reframed.drop(['High(t)', 'Low(t)', 'Volume(t)', 'Open(t-'+str(n_lagged)+')'], axis=1, inplace=True)
reframed.drop(['High(t+'+str(i)+')' for i in range(1, predict_window)], axis=1, inplace=True)
reframed.drop(['Low(t+'+str(i)+')' for i in range(1, predict_window)], axis=1, inplace=True)
reframed.drop(['Open(t+'+str(i)+')' for i in range(1, predict_window)], axis=1, inplace=True)
reframed.drop(['Volume(t+'+str(i)+')' for i in range(1, predict_window)], axis=1, inplace=True)


# Data splitting
train_X, train_y = reframed.iloc[:train_samples, :-predict_window].values, reframed.iloc[:train_samples, -predict_window:].values
val_X, val_y = reframed.iloc[train_samples:val_samples, :-predict_window].values, reframed.iloc[train_samples:val_samples, -predict_window:].values
test_X, test_y = reframed.iloc[val_samples:, :-predict_window].values, reframed.iloc[val_samples:, -predict_window:].values

# Reshaping for LSTM
train_X = train_X.reshape((train_X.shape[0], n_lagged, input_vars))
val_X = val_X.reshape((val_X.shape[0], n_lagged, input_vars))
test_X = test_X.reshape((test_X.shape[0], n_lagged, input_vars))

# %%
# RNN model
from tensorflow.keras.layers import SimpleRNN

hidden_layer_neurons = 700
batch_size = 32
epochs = 50
learning_rate = 0.0005

model_rnn = Sequential()
model_rnn.add(SimpleRNN(hidden_layer_neurons, input_shape=(train_X.shape[1], train_X.shape[2])))
model_rnn.add(Dense(1))

# Fit network
t0 = time.time()

optimizer = Adam(learning_rate=learning_rate)
model_rnn.compile(loss='mse', optimizer=optimizer)
early_stopping = EarlyStopping(monitor='val_loss', patience=6, restore_best_weights=True)
history_rnn = model_rnn.fit(train_X, train_y, epochs=epochs, batch_size=batch_size,
                    validation_data=(val_X, val_y), verbose=1, shuffle=False,
                   callbacks = [early_stopping])
t1 = time.time()
rnn_training_time = t1-t0
print("Total execution time:", t1-t0)

# Plot history
plt.plot(history_rnn.history['loss'], label='train')
plt.plot(history_rnn.history['val_loss'], label='test')
plt.legend()
plt.title("RNN Loss")
plt.show()

plt.subplots(figsize=(10, 5))

# make a prediction
yhat_train = model_rnn.predict(train_X).flatten()
yhat_val = model_rnn.predict(val_X).flatten()
yhat_test = model_rnn.predict(test_X).flatten()

# Concatenate the results
mean = scaler.mean_[scaler.feature_names_in_ == 'Close'][0]
std = np.sqrt(scaler.var_[scaler.feature_names_in_ == 'Close'][0])
y_pred = np.concatenate([yhat_train, yhat_val, yhat_test])* std + mean
y_real = np.concatenate([train_y, val_y, test_y]) * std + mean

# Plot
plt.plot(df.iloc[n_lagged:].index, y_pred, label='Predicted')
plt.plot(df.iloc[n_lagged:].index, y_real, label='Real')

plt.axvline(x = df.iloc[[train_samples]].index, color = 'yellow', label = 'Validation')
plt.axvline(x = df.iloc[[val_samples]].index, color = 'red', label = 'Test')

plt.legend()
plt.xlabel("Date")
plt.ylabel("Closing Stock price")
plt.title("RNN Results")
plt.show()

# Getting metrics
# MSE
train_rmse = np.sqrt( mean_squared_error( y_real[:train_samples], y_pred[:train_samples] ) )
val_rmse = np.sqrt( mean_squared_error( y_real[train_samples:val_samples], y_pred[train_samples:val_samples] ) )
test_rmse = np.sqrt( mean_squared_error( y_real[val_samples:], y_pred[val_samples:] ) )

# MAE
train_mae = mean_absolute_error( y_real[:train_samples], y_pred[:train_samples] )
val_mae = mean_absolute_error( y_real[train_samples:val_samples], y_pred[train_samples:val_samples] )
test_mae = mean_absolute_error( y_real[val_samples:], y_pred[val_samples:] )

# Plot
plt.plot(df.iloc[n_lagged+val_samples:].index, y_pred[val_samples:], label='Predicted')
plt.plot(df.iloc[n_lagged+val_samples:].index, y_real[val_samples:], label='Real')

plt.legend()
plt.xlabel("Date")
plt.ylabel("Closing Stock price")
plt.title("RNN Results for Test set")
plt.show()

print("Test RMSE:", test_rmse), print("Test MAE:", test_mae)
print("Validation RMSE:", val_rmse), print("Validation MAE:", val_mae)
print("Train RMSE:", train_rmse), print("Train MAE:", train_mae)
# Out:
# Epoch 1/50
# 79/79 [==============================] - 4s 31ms/step - loss: 0.1796 - val_loss: 0.0257
# Epoch 2/50
# 79/79 [==============================] - 3s 35ms/step - loss: 0.0226 - val_loss: 0.0178
# Epoch 3/50
# 79/79 [==============================] - 4s 47ms/step - loss: 0.0124 - val_loss: 0.0136
# Epoch 4/50
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0090 - val_loss: 0.0117
# Epoch 5/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.0070 - val_loss: 0.0103
# Epoch 6/50
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0058 - val_loss: 0.0101
# Epoch 7/50
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0044 - val_loss: 0.0087
# Epoch 8/50
# 79/79 [==============================] - 3s 43ms/step - loss: 0.0040 - val_loss: 0.0085
# Epoch 9/50
# 79/79 [==============================] - 3s 37ms/step - loss: 0.0035 - val_loss: 0.0079
# Epoch 10/50
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0034 - val_loss: 0.0071
# Epoch 11/50
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0032 - val_loss: 0.0066
# Epoch 12/50
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0030 - val_loss: 0.0063
# Epoch 13/50
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0028 - val_loss: 0.0061
# Epoch 14/50
# 79/79 [==============================] - 4s 48ms/step - loss: 0.0026 - val_loss: 0.0059
# Epoch 15/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.0025 - val_loss: 0.0057
# Epoch 16/50
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0023 - val_loss: 0.0056
# Epoch 17/50
# 79/79 [==============================] - 3s 40ms/step - loss: 0.0022 - val_loss: 0.0055
# Epoch 18/50
# 79/79 [==============================] - 4s 55ms/step - loss: 0.0021 - val_loss: 0.0054
# Epoch 19/50
# 79/79 [==============================] - 4s 49ms/step - loss: 0.0020 - val_loss: 0.0056
# Epoch 20/50
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0020 - val_loss: 0.0058
# Epoch 21/50
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0020 - val_loss: 0.0057
# Epoch 22/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.0020 - val_loss: 0.0058
# Epoch 23/50
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0022 - val_loss: 0.0075
# Epoch 24/50
# 79/79 [==============================] - 3s 43ms/step - loss: 0.0029 - val_loss: 0.0101
# Total execution time: 67.8841061592102
# 79/79 [==============================] - 1s 8ms/step
# 10/10 [==============================] - 0s 9ms/step
# 9/9 [==============================] - 0s 8ms/step
# Test RMSE: 46.033483201566284
# Test MAE: 39.76918296436846
# Validation RMSE: 9.50910056962327
# Validation MAE: 7.327849565694889
# Train RMSE: 10.020086561524698
# Train MAE: 7.724453515400661
# (None, None)

# %%
plot_model(model_rnn, show_shapes=True, show_layer_names=True, show_layer_activations=True)

# %%
print("Test RMSE:", test_rmse), print("Test MAE:", test_mae)

print("Validation RMSE:", val_rmse), print("Validation MAE:", val_mae)

print("Train RMSE:", train_rmse), print("Train MAE:", train_mae)

test_rmse_rnn = test_rmse
test_mae_rnn = test_mae
val_rmse_rnn = val_rmse
val_mae_rnn = val_mae
train_rmse_rnn = train_rmse
train_mae_rnn = train_mae
# Out:
# Test RMSE: 46.033483201566284
# Test MAE: 39.76918296436846
# Validation RMSE: 9.50910056962327
# Validation MAE: 7.327849565694889
# Train RMSE: 10.020086561524698
# Train MAE: 7.724453515400661

# %%
x_ticks = range(1, 32)
plt.plot(x_ticks, train_times, '-o')

plt.xlabel("Prediction Horizon")
plt.ylabel("Training times (seconds)")
plt.show()

# %% [markdown]
# # Sensitivity Analysis of RNN: Hidden layer neurons

# %%
# RNN model
from tensorflow.keras.layers import SimpleRNN

hidden_layer_neurons = [500,600,700,800]
batch_size = 32
epochs = 50
learning_rate = 0.0005
rmse_test_list = []
rmse_val_list = []
rmse_train_list = []
n=0
for hidden_neuron in hidden_layer_neurons:
    model_rnn = Sequential()
    model_rnn.add(SimpleRNN(hidden_neuron, input_shape=(train_X.shape[1], train_X.shape[2])))
    model_rnn.add(Dense(1))

    # Fit network
    t0 = time.time()

    optimizer = Adam(learning_rate=learning_rate)
    model_rnn.compile(loss='mse', optimizer=optimizer)
    early_stopping = EarlyStopping(monitor='val_loss', patience=6, restore_best_weights=True)
    history_rnn = model_rnn.fit(train_X, train_y, epochs=epochs, batch_size=batch_size,
                        validation_data=(val_X, val_y), verbose=1, shuffle=False,
                    callbacks = [early_stopping])
    t1 = time.time()
    rnn_training_time = t1-t0
    print("Total execution time:", t1-t0)
    yhat_train = model_rnn.predict(train_X).flatten()
    yhat_val = model_rnn.predict(val_X).flatten()
    yhat_test = model_rnn.predict(test_X).flatten()

    # Concatenate the results
    mean = scaler.mean_[scaler.feature_names_in_ == 'Close'][0]
    std = np.sqrt(scaler.var_[scaler.feature_names_in_ == 'Close'][0])
    y_pred = np.concatenate([yhat_train, yhat_val, yhat_test])* std + mean
    y_real = np.concatenate([train_y, val_y, test_y]) * std + mean

    train_rmse = np.sqrt( mean_squared_error( y_real[:train_samples], y_pred[:train_samples] ) )
    val_rmse = np.sqrt( mean_squared_error( y_real[train_samples:val_samples], y_pred[train_samples:val_samples] ) )
    test_rmse = np.sqrt( mean_squared_error( y_real[val_samples:], y_pred[val_samples:] ) )

    rmse_test_list.append(test_rmse)
    rmse_val_list.append(val_rmse)
    rmse_train_list.append(train_rmse)
    n+=1

df_results = pd.DataFrame(hidden_layer_neurons, columns=['Hidden Neurons'])
df_results['Test RMSE'] = rmse_test_list
df_results['Val RMSE'] = rmse_val_list
df_results['Train RMSE'] = rmse_train_list
print(df_results)
# Out:
# Epoch 1/50
# 79/79 [==============================] - 5s 51ms/step - loss: 0.0940 - val_loss: 0.0327
# Epoch 2/50
# 79/79 [==============================] - 3s 31ms/step - loss: 0.0315 - val_loss: 0.0195
# Epoch 3/50
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0113 - val_loss: 0.0233
# Epoch 4/50
# 79/79 [==============================] - 2s 28ms/step - loss: 0.0059 - val_loss: 0.0163
# Epoch 5/50
# 79/79 [==============================] - 2s 28ms/step - loss: 0.0056 - val_loss: 0.0110
# Epoch 6/50
# 79/79 [==============================] - 3s 35ms/step - loss: 0.0056 - val_loss: 0.0108
# Epoch 7/50
# 79/79 [==============================] - 4s 46ms/step - loss: 0.0046 - val_loss: 0.0098
# Epoch 8/50
# 79/79 [==============================] - 2s 28ms/step - loss: 0.0043 - val_loss: 0.0085
# Epoch 9/50
# 79/79 [==============================] - 2s 28ms/step - loss: 0.0040 - val_loss: 0.0083
# Epoch 10/50
# 79/79 [==============================] - 2s 28ms/step - loss: 0.0037 - val_loss: 0.0079
# Epoch 11/50
# 79/79 [==============================] - 2s 28ms/step - loss: 0.0035 - val_loss: 0.0078
# Epoch 12/50
# 79/79 [==============================] - 3s 40ms/step - loss: 0.0033 - val_loss: 0.0077
# Epoch 13/50
# 79/79 [==============================] - 3s 40ms/step - loss: 0.0031 - val_loss: 0.0078
# Epoch 14/50
# 79/79 [==============================] - 2s 28ms/step - loss: 0.0028 - val_loss: 0.0080
# Epoch 15/50
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0026 - val_loss: 0.0067
# Epoch 16/50
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0025 - val_loss: 0.0058
# Epoch 17/50
# 79/79 [==============================] - 2s 28ms/step - loss: 0.0024 - val_loss: 0.0059
# Epoch 18/50
# 79/79 [==============================] - 4s 45ms/step - loss: 0.0022 - val_loss: 0.0054
# Epoch 19/50
# 79/79 [==============================] - 3s 35ms/step - loss: 0.0021 - val_loss: 0.0053
# Epoch 20/50
# 79/79 [==============================] - 2s 28ms/step - loss: 0.0020 - val_loss: 0.0055
# Epoch 21/50
# 79/79 [==============================] - 2s 28ms/step - loss: 0.0019 - val_loss: 0.0056
# Epoch 22/50
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0019 - val_loss: 0.0054
# Epoch 23/50
# 79/79 [==============================] - 3s 32ms/step - loss: 0.0018 - val_loss: 0.0055
# Epoch 24/50
# 79/79 [==============================] - 4s 48ms/step - loss: 0.0018 - val_loss: 0.0053
# Epoch 25/50
# 79/79 [==============================] - 2s 28ms/step - loss: 0.0018 - val_loss: 0.0048
# Epoch 26/50
# 79/79 [==============================] - 2s 28ms/step - loss: 0.0019 - val_loss: 0.0090
# Epoch 27/50
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0024 - val_loss: 0.0049
# Epoch 28/50
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0026 - val_loss: 0.0069
# Epoch 29/50
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0032 - val_loss: 0.0055
# Epoch 30/50
# 79/79 [==============================] - 3s 42ms/step - loss: 0.0020 - val_loss: 0.0059
# Epoch 31/50
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0020 - val_loss: 0.0062
# Total execution time: 82.50011730194092
# 79/79 [==============================] - 1s 5ms/step
# 10/10 [==============================] - 0s 5ms/step
# 9/9 [==============================] - 0s 5ms/step
# Epoch 1/50
# 79/79 [==============================] - 4s 32ms/step - loss: 0.1016 - val_loss: 0.0287
# Epoch 2/50
# 79/79 [==============================] - 3s 32ms/step - loss: 0.0297 - val_loss: 0.0191
# Epoch 3/50
# 79/79 [==============================] - 4s 49ms/step - loss: 0.0138 - val_loss: 0.0155
# Epoch 4/50
# 79/79 [==============================] - 2s 31ms/step - loss: 0.0101 - val_loss: 0.0127
# Epoch 5/50
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0068 - val_loss: 0.0120
# Epoch 6/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.0050 - val_loss: 0.0107
# Epoch 7/50
# 79/79 [==============================] - 2s 28ms/step - loss: 0.0044 - val_loss: 0.0106
# Epoch 8/50
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0040 - val_loss: 0.0101
# Epoch 9/50
# 79/79 [==============================] - 3s 42ms/step - loss: 0.0035 - val_loss: 0.0098
# Epoch 10/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.0032 - val_loss: 0.0085
# Epoch 11/50
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0031 - val_loss: 0.0078
# Epoch 12/50
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0029 - val_loss: 0.0072
# Epoch 13/50
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0028 - val_loss: 0.0068
# Epoch 14/50
# 79/79 [==============================] - 4s 47ms/step - loss: 0.0026 - val_loss: 0.0066
# Epoch 15/50
# 79/79 [==============================] - 3s 35ms/step - loss: 0.0024 - val_loss: 0.0064
# Epoch 16/50
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0022 - val_loss: 0.0062
# Epoch 17/50
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0020 - val_loss: 0.0060
# Epoch 18/50
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0020 - val_loss: 0.0057
# Epoch 19/50
# 79/79 [==============================] - 3s 35ms/step - loss: 0.0019 - val_loss: 0.0056
# Epoch 20/50
# 79/79 [==============================] - 4s 47ms/step - loss: 0.0018 - val_loss: 0.0057
# Epoch 21/50
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0018 - val_loss: 0.0057
# Epoch 22/50
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0018 - val_loss: 0.0060
# Epoch 23/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.0019 - val_loss: 0.0062
# Epoch 24/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.0022 - val_loss: 0.0055
# Epoch 25/50
# 79/79 [==============================] - 4s 46ms/step - loss: 0.0025 - val_loss: 0.0057
# Epoch 26/50
# 79/79 [==============================] - 3s 38ms/step - loss: 0.0023 - val_loss: 0.0058
# Epoch 27/50
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0022 - val_loss: 0.0059
# Epoch 28/50
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0021 - val_loss: 0.0062
# Epoch 29/50
# 79/79 [==============================] - 2s 31ms/step - loss: 0.0021 - val_loss: 0.0053
# Epoch 30/50
# 79/79 [==============================] - 3s 36ms/step - loss: 0.0020 - val_loss: 0.0055
# Epoch 31/50
# 79/79 [==============================] - 4s 48ms/step - loss: 0.0022 - val_loss: 0.0051
# Epoch 32/50
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0023 - val_loss: 0.0055
# Epoch 33/50
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0022 - val_loss: 0.0057
# Epoch 34/50
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0020 - val_loss: 0.0072
# Epoch 35/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.0021 - val_loss: 0.0050
# Epoch 36/50
# 79/79 [==============================] - 4s 46ms/step - loss: 0.0020 - val_loss: 0.0062
# Epoch 37/50
# 79/79 [==============================] - 3s 38ms/step - loss: 0.0019 - val_loss: 0.0056
# Epoch 38/50
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0021 - val_loss: 0.0062
# Epoch 39/50
# 79/79 [==============================] - 2s 31ms/step - loss: 0.0021 - val_loss: 0.0059
# Epoch 40/50
# 79/79 [==============================] - 2s 31ms/step - loss: 0.0019 - val_loss: 0.0052
# Epoch 41/50
# 79/79 [==============================] - 3s 40ms/step - loss: 0.0019 - val_loss: 0.0052
# Total execution time: 111.26917624473572
# 79/79 [==============================] - 1s 6ms/step
# 10/10 [==============================] - 0s 5ms/step
# 9/9 [==============================] - 0s 6ms/step
# Epoch 1/50
# 79/79 [==============================] - 4s 36ms/step - loss: 0.1330 - val_loss: 0.0167
# Epoch 2/50
# 79/79 [==============================] - 4s 48ms/step - loss: 0.0164 - val_loss: 0.0178
# Epoch 3/50
# 79/79 [==============================] - 3s 38ms/step - loss: 0.0136 - val_loss: 0.0110
# Epoch 4/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.0069 - val_loss: 0.0095
# Epoch 5/50
# 79/79 [==============================] - 2s 31ms/step - loss: 0.0049 - val_loss: 0.0083
# Epoch 6/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.0045 - val_loss: 0.0081
# Epoch 7/50
# 79/79 [==============================] - 3s 41ms/step - loss: 0.0038 - val_loss: 0.0074
# Epoch 8/50
# 79/79 [==============================] - 4s 45ms/step - loss: 0.0037 - val_loss: 0.0069
# Epoch 9/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.0034 - val_loss: 0.0067
# Epoch 10/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.0030 - val_loss: 0.0070
# Epoch 11/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.0028 - val_loss: 0.0063
# Epoch 12/50
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0027 - val_loss: 0.0060
# Epoch 13/50
# 79/79 [==============================] - 4s 50ms/step - loss: 0.0026 - val_loss: 0.0056
# Epoch 14/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.0024 - val_loss: 0.0053
# Epoch 15/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.0022 - val_loss: 0.0052
# Epoch 16/50
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0022 - val_loss: 0.0052
# Epoch 17/50
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0022 - val_loss: 0.0051
# Epoch 18/50
# 79/79 [==============================] - 4s 46ms/step - loss: 0.0019 - val_loss: 0.0049
# Epoch 19/50
# 79/79 [==============================] - 3s 41ms/step - loss: 0.0019 - val_loss: 0.0048
# Epoch 20/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.0019 - val_loss: 0.0047
# Epoch 21/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.0021 - val_loss: 0.0047
# Epoch 22/50
# 79/79 [==============================] - 2s 31ms/step - loss: 0.0022 - val_loss: 0.0050
# Epoch 23/50
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0021 - val_loss: 0.0049
# Epoch 24/50
# 79/79 [==============================] - 4s 50ms/step - loss: 0.0021 - val_loss: 0.0056
# Epoch 25/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.0018 - val_loss: 0.0049
# Epoch 26/50
# 79/79 [==============================] - 2s 31ms/step - loss: 0.0018 - val_loss: 0.0046
# Epoch 27/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.0018 - val_loss: 0.0064
# Epoch 28/50
# 79/79 [==============================] - 2s 31ms/step - loss: 0.0025 - val_loss: 0.0056
# Epoch 29/50
# 79/79 [==============================] - 4s 49ms/step - loss: 0.0035 - val_loss: 0.0075
# Epoch 30/50
# 79/79 [==============================] - 3s 37ms/step - loss: 0.0032 - val_loss: 0.0049
# Epoch 31/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.0030 - val_loss: 0.0047
# Epoch 32/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.0027 - val_loss: 0.0065
# Total execution time: 90.0710883140564
# 79/79 [==============================] - 1s 5ms/step
# 10/10 [==============================] - 0s 5ms/step
# 9/9 [==============================] - 0s 5ms/step
# Epoch 1/50
# 79/79 [==============================] - 5s 46ms/step - loss: 0.2011 - val_loss: 0.0421
# Epoch 2/50
# 79/79 [==============================] - 3s 43ms/step - loss: 0.0282 - val_loss: 0.0239
# Epoch 3/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.0201 - val_loss: 0.0134
# Epoch 4/50
# 79/79 [==============================] - 2s 31ms/step - loss: 0.0087 - val_loss: 0.0122
# Epoch 5/50
# 79/79 [==============================] - 2s 31ms/step - loss: 0.0064 - val_loss: 0.0108
# Epoch 6/50
# 79/79 [==============================] - 3s 36ms/step - loss: 0.0061 - val_loss: 0.0103
# Epoch 7/50
# 79/79 [==============================] - 4s 51ms/step - loss: 0.0050 - val_loss: 0.0095
# Epoch 8/50
# 79/79 [==============================] - 2s 31ms/step - loss: 0.0042 - val_loss: 0.0093
# Epoch 9/50
# 79/79 [==============================] - 2s 31ms/step - loss: 0.0036 - val_loss: 0.0084
# Epoch 10/50
# 79/79 [==============================] - 2s 31ms/step - loss: 0.0034 - val_loss: 0.0086
# Epoch 11/50
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0031 - val_loss: 0.0079
# Epoch 12/50
# 79/79 [==============================] - 4s 51ms/step - loss: 0.0031 - val_loss: 0.0071
# Epoch 13/50
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0031 - val_loss: 0.0068
# Epoch 14/50
# 79/79 [==============================] - 3s 32ms/step - loss: 0.0027 - val_loss: 0.0065
# Epoch 15/50
# 79/79 [==============================] - 3s 32ms/step - loss: 0.0027 - val_loss: 0.0061
# Epoch 16/50
# 79/79 [==============================] - 2s 31ms/step - loss: 0.0026 - val_loss: 0.0059
# Epoch 17/50
# 79/79 [==============================] - 4s 50ms/step - loss: 0.0024 - val_loss: 0.0058
# Epoch 18/50
# 79/79 [==============================] - 3s 37ms/step - loss: 0.0023 - val_loss: 0.0057
# Epoch 19/50
# 79/79 [==============================] - 2s 31ms/step - loss: 0.0021 - val_loss: 0.0056
# Epoch 20/50
# 79/79 [==============================] - 2s 31ms/step - loss: 0.0022 - val_loss: 0.0054
# Epoch 21/50
# 79/79 [==============================] - 2s 31ms/step - loss: 0.0020 - val_loss: 0.0054
# Epoch 22/50
# 79/79 [==============================] - 4s 46ms/step - loss: 0.0021 - val_loss: 0.0052
# Epoch 23/50
# 79/79 [==============================] - 3s 43ms/step - loss: 0.0019 - val_loss: 0.0055
# Epoch 24/50
# 79/79 [==============================] - 2s 31ms/step - loss: 0.0018 - val_loss: 0.0055
# Epoch 25/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.0017 - val_loss: 0.0066
# Epoch 26/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 27/50
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0025 - val_loss: 0.0074
# Epoch 28/50
# 79/79 [==============================] - 4s 48ms/step - loss: 0.0032 - val_loss: 0.0060
# Total execution time: 81.9690477848053
# 79/79 [==============================] - 1s 5ms/step
# 10/10 [==============================] - 0s 5ms/step
# 9/9 [==============================] - 0s 5ms/step
#    Hidden Neurons  Test RMSE  Val RMSE  Train RMSE
# 0             500  41.992106  8.941198    7.548739
# 1             600  40.055675  9.159672   10.638802
# 2             700  32.737685  8.706365    8.410294
# 3             800  40.855375  9.262516    9.749775

# %% [markdown]
# # Long term Predictive power RNN

# %%
train_rmse = []
val_rmse = []
test_rmse = []

train_mae = []
val_mae = []
test_mae = []

train_times = []

n_lagged = 50
for predict_window in range(1, 32):

    # frame as supervised learning
    reframed = series_to_supervised(df, n_lagged, predict_window)

    # Dropping future variables
    # At time "t", we only have Open(t) and want to predict Close(t), so we can drop High(t), Volume(t) and Low(t)
    # Also we will drop Open(t-1) because each time step needs to have exactly 4 variables. If we add more time steps we will have
    # a remaining Variable (Open(t)) to spare, so we will replace Open(t-1) with Open(t) for the first lagged variable.
    reframed.drop(['High(t)', 'Low(t)', 'Volume(t)', 'Open(t-'+str(n_lagged)+')'], axis=1, inplace=True)
    reframed.drop(['High(t+'+str(i)+')' for i in range(1, predict_window)], axis=1, inplace=True)
    reframed.drop(['Low(t+'+str(i)+')' for i in range(1, predict_window)], axis=1, inplace=True)
    reframed.drop(['Open(t+'+str(i)+')' for i in range(1, predict_window)], axis=1, inplace=True)
    reframed.drop(['Volume(t+'+str(i)+')' for i in range(1, predict_window)], axis=1, inplace=True)


    # Data splitting
    train_X, train_y = reframed.iloc[:train_samples, :-predict_window].values, reframed.iloc[:train_samples, -predict_window:].values
    val_X, val_y = reframed.iloc[train_samples:val_samples, :-predict_window].values, reframed.iloc[train_samples:val_samples, -predict_window:].values
    test_X, test_y = reframed.iloc[val_samples:, :-predict_window].values, reframed.iloc[val_samples:, -predict_window:].values

    # Reshaping for LSTM
    train_X = train_X.reshape((train_X.shape[0], n_lagged, input_vars))
    val_X = val_X.reshape((val_X.shape[0], n_lagged, input_vars))
    test_X = test_X.reshape((test_X.shape[0], n_lagged, input_vars))

    # Defining model for LSTM
    optimizer = Adam(learning_rate=learning_rate)

    model_rnn = Sequential()
    model_rnn.add(SimpleRNN(hidden_layer_neurons, input_shape=(train_X.shape[1], train_X.shape[2])))
    model_rnn.add(Dense(predict_window))
    model_rnn.compile(loss='mse', optimizer=optimizer)

    # Fit network
    t0 = time.time()
    model_rnn.fit(train_X, train_y, epochs=epochs, batch_size=batch_size,
                        validation_data=(val_X, val_y), shuffle=False,
                       callbacks = [early_stopping])
    t1 = time.time()

    train_times.append(t1-t0)

    # Predictions
    yhat_train = model_rnn.predict(train_X)*std + mean
    yhat_val = model_rnn.predict(val_X)*std + mean
    yhat_test = model_rnn.predict(test_X)*std + mean

    train_rmse.append(np.mean([np.sqrt(mean_squared_error(y_real*std + mean, y_pred)) for y_real, y_pred in zip(train_y, yhat_train)]))
    val_rmse.append(np.mean([np.sqrt(mean_squared_error(y_real*std + mean, y_pred)) for y_real, y_pred in zip(val_y, yhat_val)]))
    test_rmse.append(np.mean([np.sqrt(mean_squared_error(y_real*std + mean, y_pred)) for y_real, y_pred in zip(test_y, yhat_test)]))

    train_mae.append(np.mean([mean_absolute_error(y_real*std + mean, y_pred) for y_real, y_pred in zip(train_y, yhat_train)]))
    val_mae.append(np.mean([mean_absolute_error(y_real*std + mean, y_pred) for y_real, y_pred in zip(val_y, yhat_val)]))
    test_mae.append(np.mean([mean_absolute_error(y_real*std + mean, y_pred) for y_real, y_pred in zip(test_y, yhat_test)]))
# Out:
# Epoch 1/50
# 79/79 [==============================] - 5s 47ms/step - loss: 0.2014 - val_loss: 0.0348
# Epoch 2/50
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0376 - val_loss: 0.0156
# Epoch 3/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.0172 - val_loss: 0.0107
# Epoch 4/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.0088 - val_loss: 0.0105
# Epoch 5/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.0047 - val_loss: 0.0078
# Epoch 6/50
# 79/79 [==============================] - 3s 42ms/step - loss: 0.0044 - val_loss: 0.0073
# Epoch 7/50
# 79/79 [==============================] - 3s 44ms/step - loss: 0.0034 - val_loss: 0.0068
# Epoch 8/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.0030 - val_loss: 0.0066
# Epoch 9/50
# 79/79 [==============================] - 2s 31ms/step - loss: 0.0027 - val_loss: 0.0064
# Epoch 10/50
# 79/79 [==============================] - 2s 31ms/step - loss: 0.0027 - val_loss: 0.0061
# Epoch 11/50
# 79/79 [==============================] - 3s 32ms/step - loss: 0.0027 - val_loss: 0.0058
# Epoch 12/50
# 79/79 [==============================] - 4s 53ms/step - loss: 0.0028 - val_loss: 0.0057
# Epoch 13/50
# 79/79 [==============================] - 3s 32ms/step - loss: 0.0027 - val_loss: 0.0056
# Epoch 14/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.0026 - val_loss: 0.0056
# Epoch 15/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.0025 - val_loss: 0.0058
# Epoch 16/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.0025 - val_loss: 0.0060
# Epoch 17/50
# 79/79 [==============================] - 4s 47ms/step - loss: 0.0025 - val_loss: 0.0058
# Epoch 18/50
# 79/79 [==============================] - 3s 37ms/step - loss: 0.0032 - val_loss: 0.0078
# Epoch 19/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.0032 - val_loss: 0.0066
# 79/79 [==============================] - 1s 6ms/step
# 10/10 [==============================] - 0s 6ms/step
# 9/9 [==============================] - 0s 6ms/step
# Epoch 1/50
# 79/79 [==============================] - 4s 32ms/step - loss: 0.1146 - val_loss: 0.0532
# Epoch 2/50
# 79/79 [==============================] - 4s 52ms/step - loss: 0.0457 - val_loss: 0.0328
# Epoch 3/50
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0236 - val_loss: 0.0279
# Epoch 4/50
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0145 - val_loss: 0.0193
# Epoch 5/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.0113 - val_loss: 0.0141
# Epoch 6/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.0087 - val_loss: 0.0135
# Epoch 7/50
# 79/79 [==============================] - 3s 43ms/step - loss: 0.0060 - val_loss: 0.0124
# Epoch 8/50
# 79/79 [==============================] - 3s 40ms/step - loss: 0.0066 - val_loss: 0.0111
# Epoch 9/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.0053 - val_loss: 0.0107
# Epoch 10/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.0049 - val_loss: 0.0101
# Epoch 11/50
# 79/79 [==============================] - 2s 31ms/step - loss: 0.0046 - val_loss: 0.0100
# Epoch 12/50
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0045 - val_loss: 0.0097
# Epoch 13/50
# 79/79 [==============================] - 4s 50ms/step - loss: 0.0044 - val_loss: 0.0093
# Epoch 14/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.0041 - val_loss: 0.0092
# Epoch 15/50
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0040 - val_loss: 0.0091
# Epoch 16/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.0040 - val_loss: 0.0093
# Epoch 17/50
# 79/79 [==============================] - 3s 32ms/step - loss: 0.0038 - val_loss: 0.0090
# Epoch 18/50
# 79/79 [==============================] - 4s 50ms/step - loss: 0.0038 - val_loss: 0.0089
# Epoch 19/50
# 79/79 [==============================] - 4s 56ms/step - loss: 0.0037 - val_loss: 0.0091
# Epoch 20/50
# 79/79 [==============================] - 5s 67ms/step - loss: 0.0038 - val_loss: 0.0088
# Epoch 21/50
# 79/79 [==============================] - 7s 82ms/step - loss: 0.0036 - val_loss: 0.0089
# Epoch 22/50
# 79/79 [==============================] - 3s 32ms/step - loss: 0.0035 - val_loss: 0.0091
# Epoch 23/50
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0035 - val_loss: 0.0095
# Epoch 24/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.0035 - val_loss: 0.0093
# Epoch 25/50
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0035 - val_loss: 0.0101
# Epoch 26/50
# 79/79 [==============================] - 4s 50ms/step - loss: 0.0034 - val_loss: 0.0098
# 79/79 [==============================] - 1s 6ms/step
# 10/10 [==============================] - 0s 5ms/step
# 9/9 [==============================] - 0s 5ms/step
# Epoch 1/50
# 79/79 [==============================] - 4s 32ms/step - loss: 0.1122 - val_loss: 0.0899
# Epoch 2/50
# 79/79 [==============================] - 2s 31ms/step - loss: 0.0460 - val_loss: 0.0313
# Epoch 3/50
# 79/79 [==============================] - 3s 40ms/step - loss: 0.0262 - val_loss: 0.0303
# Epoch 4/50
# 79/79 [==============================] - 4s 45ms/step - loss: 0.
50
# 79/79 [==============================] - 2s 31ms/step - loss: 0.4865 - val_loss: 0.3646
# Epoch 7/50
# 79/79 [==============================] - 2s 31ms/step - loss: 0.4221 - val_loss: 13.2893
# Epoch 8/50
# 79/79 [==============================] - 4s 47ms/step - loss: 0.7565 - val_loss: 0.3027
# Epoch 9/50
# 79/79 [==============================] - 3s 39ms/step - loss: 0.6610 - val_loss: 1.6143
# Epoch 10/50
# 79/79 [==============================] - 2s 32ms/step - loss: 0.4219 - val_loss: 1.3965
# Epoch 11/50
# 79/79 [==============================] - 2s 31ms/step - loss: 0.4398 - val_loss: 1.3267
# Epoch 12/50
# 79/79 [==============================] - 2s 31ms/step - loss: 0.4422 - val_loss: 1.3052
# Epoch 13/50
# 79/79 [==============================] - 3s 40ms/step - loss: 0.4937 - val_loss: 1.5051
# Epoch 14/50
# 79/79 [==============================] - 4s 49ms/step - loss: 0.4610 - val_loss: 1.3271
# 79/79 [==============================] - 1s 5ms/step
# 10/10 [==============================] - 0s 6ms/step
# 8/8 [==============================] - 0s 5ms/step
# Epoch 1/50
# 79/79 [==============================] - 4s 32ms/step - loss: 0.1813 - val_loss: 0.5391
# Epoch 2/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.4890 - val_loss: 2.3356
# Epoch 3/50
# 79/79 [==============================] - 4s 46ms/step - loss: 0.4253 - val_loss: 1.6838
# Epoch 4/50
# 79/79 [==============================] - 3s 43ms/step - loss: 0.4240 - val_loss: 1.6384
# Epoch 5/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.4315 - val_loss: 1.5836
# Epoch 6/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.4395 - val_loss: 1.5389
# Epoch 7/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.4296 - val_loss: 1.5161
# 79/79 [==============================] - 1s 6ms/step
# 10/10 [==============================] - 0s 5ms/step
# 8/8 [==============================] - 0s 6ms/step
# Epoch 1/50
# 79/79 [==============================] - 5s 40ms/step - loss: 0.1811 - val_loss: 0.4459
# Epoch 2/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.8093 - val_loss: 2.8391
# Epoch 3/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.2911 - val_loss: 0.7640
# Epoch 4/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.2278 - val_loss: 1.9864
# Epoch 5/50
# 79/79 [==============================] - 3s 37ms/step - loss: 0.2903 - val_loss: 0.4473
# Epoch 6/50
# 79/79 [==============================] - 4s 46ms/step - loss: 0.3835 - val_loss: 1.4071
# Epoch 7/50
# 79/79 [==============================] - 2s 30ms/step - loss: 0.3768 - val_loss: 1.7825
# 79/79 [==============================] - 1s 5ms/step
# 10/10 [==============================] - 0s 6ms/step
# 8/8 [==============================] - 0s 6ms/step

# %%
x_ticks = range(1, 32)
plt.plot(x_ticks, train_rmse, '-o', label='Train')
plt.plot(x_ticks, val_rmse, '-o', label='Validation')
plt.plot(x_ticks, test_rmse, '-o', label='Test')

plt.title("RMSE evolution for different prediction horizon")
plt.xlabel("Prediction Horizon")
plt.ylabel("RMSE")
plt.legend()
plt.show()

# %%
rnn_longterm_rmse = test_rmse
rnn_longterm_mae = test_mae

# %%
x_ticks = range(1, 32)
plt.plot(x_ticks, train_mae, '-o', label='Train')
plt.plot(x_ticks, val_mae, '-o', label='Validation')
plt.plot(x_ticks, test_mae, '-o', label='Test')

plt.title("MAE evolution for different prediction horizon")
plt.xlabel("Prediction Horizon")
plt.ylabel("MAE")
plt.legend()
plt.show()

# %%
x_ticks = range(1, 32)
plt.plot(x_ticks, train_times, '-o')

plt.xlabel("Prediction Horizon")
plt.ylabel("Training times (seconds)")
plt.title("RNN Training times")
plt.show()

# %% [markdown]
# # Transformer

# %%
# Fixing open variable
df = df.shift(-1).iloc[:-1]

# %%
import torch
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import time
import matplotlib.pyplot as plt

def floatation(df, attributes):
    for var in attributes:
        df[var] = df[var].astype(str)            # converting to string
        df[var] = df[var].str.replace(',', '.')  # replacing the commas with dot decimal separatpr
        df[var] = df[var].astype(np.float32)     # converting the values into dot
    return df

def sequencing(dataset, start_index=0, end_index=None, history_size=50, step=1):
    data = []
    start_index = start_index + history_size
    if end_index is None:
        end_index = len(dataset)
    for i in range(start_index, end_index):
        indices = range(i - history_size, i, step)
        data.append(dataset[indices])
    return np.array(data)

def partition(data, pTrain=0.7, pVal = 0.5, save_path=None):
    # Data is already normalized
    sequencedData = sequencing(data, start_index=0, end_index=None, history_size=50, step=1)

    dataTrain = sequencedData[:train_samples]
    dataVal = sequencedData[train_samples:val_samples]
    dataTest = sequencedData[val_samples:]

    return dataTrain, dataVal, dataTest

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

def split(trainData, predicting_window):
    # Adapting targets to have a predicting window > 1
    targets = trainData[:, predicting_window:, :].tolist()
    for i in range(len(targets)): # samples dim
        for k in range(1, trainData.shape[1]-predicting_window+1):
            targets[i][k-1] = trainData[i, k:k+predicting_window, 3]
    targets = np.array(targets)
    trainData = trainData[:, :-predicting_window, :]

    inputs = torch.tensor(trainData, device=device)
    targets = torch.tensor(targets, device=device)
    return inputs, targets

def createLoaders(dataTrain, dataVal, dataTest, predicting_window, batchSize=32):
    XTrain, YTrain = split(dataTrain, predicting_window)
    XVal, YVal = split(dataVal, predicting_window)
    XTest, YTest = split(dataTest, predicting_window)

    trainDS = torch.utils.data.TensorDataset(XTrain, YTrain)
    valDS = torch.utils.data.TensorDataset(XVal, YVal)
    testDS = torch.utils.data.TensorDataset(XTest, YTest)

    trainLoader = torch.utils.data.DataLoader(trainDS, batch_size=batchSize)
    valLoader = torch.utils.data.DataLoader(valDS, batch_size=batchSize)
    testLoader = torch.utils.data.DataLoader(testDS, batch_size=batchSize)

    return trainLoader, valLoader, testLoader

import torch.nn as nn
import math

class MultiHeadAttention(nn.Module):
    def __init__(self, D, H):
        super(MultiHeadAttention, self).__init__()
        self.H = H # number of heads
        self.D = D # dimension

        self.wq = nn.Linear(D, D*H)
        self.wk = nn.Linear(D, D*H)
        self.wv = nn.Linear(D, D*H)

        self.dense = nn.Linear(D*H, D)

    def concat_heads(self, x):
        '''(B, H, S, D) => (B, S, D*H)'''
        B, H, S, D = x.shape
        x = x.permute((0, 2, 1, 3)).contiguous()  # (B, S, H, D)
        x = x.reshape((B, S, H*D))   # (B, S, D*H)
        return x

    def split_heads(self, x):
        '''(B, S, D*H) => (B, H, S, D)'''
        B, S, D_H = x.shape
        x = x.reshape(B, S, self.H, self.D)    # (B, S, H, D)
        x = x.permute((0, 2, 1, 3))  # (B, H, S, D)
        return x

    def forward(self, x, mask):

        q = self.wq(x)  # (B, S, D*H)
        k = self.wk(x)  # (B, S, D*H)
        v = self.wv(x)  # (B, S, D*H)

        q = self.split_heads(q)  # (B, H, S, D)
        k = self.split_heads(k)  # (B, H, S, D)
        v = self.split_heads(v)  # (B, H, S, D)

        attention_scores = torch.matmul(q, k.transpose(-1, -2)) #(B,H,S,S)
        attention_scores = attention_scores / math.sqrt(self.D)

        # add the mask to the scaled tensor.
        if mask is not None:
            attention_scores += (mask * -1e9)

        attention_weights = nn.Softmax(dim=-1)(attention_scores)
        scaled_attention = torch.matmul(attention_weights, v)  # (B, H, S, D)
        concat_attention = self.concat_heads(scaled_attention) # (B, S, D*H)
        output = self.dense(concat_attention)  # (B, S, D)

        return output, attention_weights

def get_angles(pos, i, D):
    angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(D))
    return pos * angle_rates


def positional_encoding(D, position=50, dim=3, device=device):
    angle_rads = get_angles(np.arange(position)[:, np.newaxis],
                            np.arange(D)[np.newaxis, :],
                            D)
    # apply sin to even indices in the array; 2i
    angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
    # apply cos to odd indices in the array; 2i+1
    angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
    if dim == 3:
        pos_encoding = angle_rads[np.newaxis, ...]
    elif dim == 4:
        pos_encoding = angle_rads[np.newaxis,np.newaxis,  ...]
    return torch.tensor(pos_encoding, device=device)

# function that implement the look_ahead mask for masking future time steps.
def create_look_ahead_mask(size, device=device):
    mask = torch.ones((size, size), device=device)
    mask = torch.triu(mask, diagonal=1)
    return mask  # (size, size)


class TransformerLayer(nn.Module):
    def __init__(self, D, H, hidden_mlp_dim, dropout_rate):
        super(TransformerLayer, self).__init__()
        self.dropout_rate = dropout_rate
        self.mlp_hidden = nn.Linear(D, hidden_mlp_dim)
        self.mlp_out = nn.Linear(hidden_mlp_dim, D)
        self.layernorm1 = nn.LayerNorm(D, eps=1e-9)
        self.layernorm2 = nn.LayerNorm(D, eps=1e-9)
        self.dropout1 = nn.Dropout(dropout_rate)
        self.dropout2 = nn.Dropout(dropout_rate)

        self.mha = MultiHeadAttention(D, H)


    def forward(self, x, look_ahead_mask):

        attn, attn_weights = self.mha(x, look_ahead_mask)  # (B, S, D)
        attn = self.dropout1(attn) # (B,S,D)
        attn = self.layernorm1(attn + x) # (B,S,D)

        mlp_act = torch.relu(self.mlp_hidden(attn))
        mlp_act = self.mlp_out(mlp_act)
        mlp_act = self.dropout2(mlp_act)

        output = self.layernorm2(mlp_act + attn)  # (B, S, D)

        return output, attn_weights
class Transformer(nn.Module):
    '''Transformer Decoder Implementating several Decoder Layers.
    '''
    def __init__(self, num_layers, D, H, hidden_mlp_dim, inp_features, out_features, dropout_rate):
        super(Transformer, self).__init__()
        self.sqrt_D = torch.tensor(math.sqrt(D))
        self.num_layers = num_layers
        self.input_projection = nn.Linear(inp_features, D) # multivariate input
        self.output_projection = nn.Linear(D, out_features) # multivariate output
        self.pos_encoding = positional_encoding(D)
        self.dec_layers = nn.ModuleList([TransformerLayer(D, H, hidden_mlp_dim,
                                        dropout_rate=dropout_rate
                                       ) for _ in range(num_layers)])
        self.dropout = nn.Dropout(dropout_rate)

    def forward(self, x, mask):
        B, S, D = x.shape
        attention_weights = {}
        x = self.input_projection(x)
        x *= self.sqrt_D

        x += self.pos_encoding[:, :S, :]

        x = self.dropout(x)

        for i in range(self.num_layers):
            x, block = self.dec_layers[i](x=x,
                                          look_ahead_mask=mask)
            attention_weights['decoder_layer{}'.format(i + 1)] = block

        x = self.output_projection(x)

        return x, attention_weights # (B,S,S)

# num_layers = [1,2,3,4]
# D = [32, 32*2, 32*4, 32*8]
# H = [1, 2, 4, 6]
# hidden_mlp_dim = [32*3, 32*6, 32 * 8, 32*10]

# it = 50
# best_loss = 100
# for i in range(it):
#   layer = num_layers[np.random.choice(4)]
#   my_D = D[np.random.choice(4)]
#   my_H = H[np.random.choice(4)]
#   hidden = hidden_mlp_dim[np.random.choice(4)]

#   transformer = Transformer(num_layers=layer, D=my_D, H=my_H, hidden_mlp_dim=hidden,
#                             inp_features=5, out_features=1, dropout_rate=0.1).to(device)
#   optimizer = torch.optim.RMSprop(transformer.parameters(),
#                                   lr=0.00001)


#   n_epochs = 300
#   attributes = list(df.columns)
#   df1 = floatation(df, attributes)
#   data = df1.values
#   losses, val_losses, test_losses = [], [],[]
#   trainData, valData, testData = partition(data)
#   trainDataset, valDataset, testDataset = createLoaders(trainData, valData, testData)
#   niter = len(trainDataset)

#   y_train_arr = []
#   y_pred_train = []

#   y_val_arr = []
#   y_pred_val = []

#   y_test_arr = []
#   y_pred_test = []

#   for e in range(n_epochs):

#       # one epoch on train set
#       transformer.train()
#       sum_train_loss = 0.0
#       for x,y in trainDataset:
#           S = x.shape[1]
#           mask = create_look_ahead_mask(S)
#           out, _ = transformer(x, mask)
#           loss = torch.nn.MSELoss()(out, y)
#           sum_train_loss += loss.item()
#           loss.backward()
#           optimizer.step()

#           if e == n_epochs-1:
#               y_train_arr.append(y[:, -1, 0])
#               y_pred_train.append(out[:, -1, 0])
#       losses.append(sum_train_loss / niter)

#       # Evaluate on val set
#       transformer.eval()
#       sum_val_loss = 0.0
#       for i, (x, y) in enumerate(valDataset):
#           S = x.shape[1]
#           mask = create_look_ahead_mask(S)
#           out, _ = transformer(x, mask)
#           loss = torch.nn.MSELoss()(out, y)
#           sum_val_loss += loss.item()
#           if e == n_epochs-1:
#               y_val_arr.append(y[:, -1, 0])
#               y_pred_val.append(out[:, -1, 0])

#       val_losses.append(sum_val_loss / (i + 1))
#       transformer.eval()
#       sum_test_loss = 0.0
#       for i, (x, y) in enumerate(testDataset):
#           S = x.shape[1]
#           mask = create_look_ahead_mask(S)
#           out, _ = transformer(x, mask)
#           loss = torch.nn.MSELoss()(out, y)
#           sum_test_loss += loss.item()

#           if e == n_epochs-1:
#               y_test_arr.append(y[:, -1, 0])
#               y_pred_test.append(out[:, -1, 0])
#       test_losses.append(sum_test_loss / (i + 1))

#   if val_losses[-1] < best_loss:
#     print(val_losses[-1])
#     print(layer, my_D, my_H, hidden)
#     best_loss = val_losses[-1]

# %%
layer = 1
my_D = 256
my_H = 4
hidden = 96
t0 = time.time()
transformer = Transformer(num_layers=layer, D=my_D, H=my_H, hidden_mlp_dim=hidden,
                          inp_features=5, out_features=1, dropout_rate=0.1).to(device)
optimizer = torch.optim.RMSprop(transformer.parameters(),
                                lr=0.00001)


n_epochs = 130
attributes = list(df.columns)
df1 = floatation(df, attributes)
data = df1.values
losses, val_losses, test_losses = [], [],[]
trainData, valData, testData = partition(data)
trainDataset, valDataset, testDataset = createLoaders(trainData, valData, testData, predicting_window=1)
niter = len(trainDataset)

y_train_arr = []
y_pred_train = []

y_val_arr = []
y_pred_val = []

y_test_arr = []
y_pred_test = []

for e in range(n_epochs):

    # one epoch on train set
    transformer.train()
    sum_train_loss = 0.0
    for x,y in trainDataset:
        S = x.shape[1]
        mask = create_look_ahead_mask(S)
        out, _ = transformer(x, mask)
        loss = torch.nn.MSELoss()(out, y)
        sum_train_loss += loss.item()
        loss.backward()
        optimizer.step()

        if e == n_epochs-1:
            y_train_arr.append(y[:, -1, 0])
            y_pred_train.append(out[:, -1, 0])
    losses.append(sum_train_loss / niter)

    # Evaluate on val set
    transformer.eval()
    sum_val_loss = 0.0
    for i, (x, y) in enumerate(valDataset):
        S = x.shape[1]
        mask = create_look_ahead_mask(S)
        out, _ = transformer(x, mask)
        loss = torch.nn.MSELoss()(out, y)
        sum_val_loss += loss.item()
        if e == n_epochs-1:
            y_val_arr.append(y[:, -1, 0])
            y_pred_val.append(out[:, -1, 0])

    val_losses.append(sum_val_loss / (i + 1))
    transformer.eval()
    sum_test_loss = 0.0
    for i, (x, y) in enumerate(testDataset):
        S = x.shape[1]
        mask = create_look_ahead_mask(S)
        out, _ = transformer(x, mask)
        loss = torch.nn.MSELoss()(out, y)
        sum_test_loss += loss.item()

        if e == n_epochs-1:
            y_test_arr.append(y[:, -1, 0])
            y_pred_test.append(out[:, -1, 0])
    test_losses.append(sum_test_loss / (i + 1))



print("Training Loss:", losses[-1]), print("Validation Loss:", val_losses[-1]), print("Test Loss:", test_losses[-1])
transformer_training_time = time.time()-t0
print("Training time:", transformer_training_time)
plt.plot(losses, label='train')
plt.plot(val_losses, label='val')
plt.plot(test_losses, label='test')
plt.legend()
plt.title("Transformer Loss")
# Out:
# Training Loss: 0.029143842573784575
# Validation Loss: 0.16246988885104657
# Test Loss: 2.1937261753612094
# Training time: 62.37935256958008
# Text(0.5, 1.0, 'Transformer Loss')

# %%
aux = []
[aux.extend(x) for x in y_train_arr]
y_train_arr = np.array([x.cpu() for x in aux])

aux = []
[aux.extend(x.cpu().detach().numpy()) for x in y_pred_train]
y_pred_train = np.array(aux)


aux = []
[aux.extend(x.cpu().detach().numpy()) for x in y_val_arr]
y_val_arr = np.array(aux)

aux = []
[aux.extend(x.cpu().detach().numpy()) for x in y_pred_val]
y_pred_val = np.array(aux)


aux = []
[aux.extend(x.cpu().detach().numpy()) for x in y_test_arr]
y_test_arr = np.array(aux)

aux = []
[aux.extend(x.cpu().detach().numpy()) for x in y_pred_test]
y_pred_test = np.array(aux)


mean = scaler.mean_[3]
std = np.sqrt(scaler.var_[3])

y_train_arr = y_train_arr * std + mean
y_pred_train = y_pred_train * std + mean
y_val_arr = y_val_arr * std + mean
y_pred_val = y_pred_val * std + mean
y_test_arr = y_test_arr * std + mean
y_pred_test = y_pred_test * std + mean

# %%
plt.subplots(figsize=(10, 5))

plt.plot(df.index[50:], np.concatenate([y_train_arr, y_val_arr, y_test_arr]), label='Real')
plt.plot(df.index[50:], np.concatenate([y_pred_train, y_pred_val, y_pred_test]), label='Prediction')

plt.axvline(x = df.iloc[[train_samples]].index, color = 'yellow', label = 'Validation')
plt.axvline(x = df.iloc[[val_samples]].index, color = 'red', label = 'Test')

plt.legend()
plt.xlabel("Date")
plt.ylabel("Closing Stock price")
plt.title("Transformer Results")
plt.show()

# %%
# Getting metrics
# MSE
train_rmse_transformer = np.sqrt( mean_squared_error( y_train_arr, y_pred_train ) )
val_rmse_transformer = np.sqrt( mean_squared_error( y_val_arr, y_pred_val ) )
test_rmse_transformer = np.sqrt( mean_squared_error( y_test_arr, y_pred_test ) )

# MAE
train_mae_transformer = mean_absolute_error(  y_train_arr, y_pred_train  )
val_mae_transformer = mean_absolute_error( y_val_arr, y_pred_val )
test_mae_transformer = mean_absolute_error( y_test_arr, y_pred_test )

# %% [markdown]
# # Results

# %%
# RMSE results
x_arr = np.arange(3)*2
plt.bar(x_arr-0.3, [train_rmse_LSTM, train_rmse_rnn, train_rmse_transformer], label='Train', width=0.3)
plt.bar(x_arr, [val_rmse_LSTM, val_rmse_rnn, val_rmse_transformer], label='Validation',width=0.3)
plt.bar(x_arr+0.3, [test_rmse_LSTM, test_rmse_rnn, test_rmse_transformer], label='Test', width=0.3)

plt.xticks(x_arr, ['LSTM', 'RNN', 'Transformer'])
plt.xlabel("Models")
plt.ylabel("Performance")
plt.title("RMSE")
plt.legend()
plt.show()

# %%
# MAE results
x_arr = np.arange(3)*2
plt.bar(x_arr-0.3, [train_mae_LSTM, train_mae_rnn, train_mae_transformer], label='Train', width=0.3)
plt.bar(x_arr, [val_mae_LSTM, val_mae_rnn, val_mae_transformer], label='Validation', width=0.3)
plt.bar(x_arr+0.3, [test_mae_LSTM, test_mae_rnn, test_mae_transformer], label='Test', width=0.3)

plt.xticks(x_arr, ['LSTM', 'RNN', 'Transformer'])
plt.xlabel("Models")
plt.ylabel("Performance")
plt.title("MAE")
plt.legend()
plt.show()

# %%
# Training times
plt.bar(x_arr, [lstm_training_time, rnn_training_time, transformer_training_time])
plt.xlabel("Models")
plt.ylabel("Seconds")
plt.title("Training Times")

plt.xticks(x_arr, ['LSTM', 'RNN', 'Transformer'])

plt.show()

# %% [markdown]
# # Longterm Transformer

# %%
layer = 1
my_D = 256
my_H = 4
hidden = 500


total_train_rmse = []
total_val_rmse = []
total_test_rmse = []
total_train_mae = []
total_val_mae = []
total_test_mae = []

total_time = []

for predicting_window in range(1, 32):
    t0 = time.time()
    transformer = Transformer(num_layers=layer, D=my_D, H=my_H, hidden_mlp_dim=hidden,
                              inp_features=5, out_features=predicting_window, dropout_rate=0.1).to(device)
    optimizer = torch.optim.RMSprop(transformer.parameters(),
                                    lr=0.00001)


    n_epochs = 130
    attributes = list(df.columns)
    df1 = floatation(df, attributes)
    data = df1.values
    losses, val_losses, test_losses = [], [],[]
    trainData, valData, testData = partition(data)
    trainDataset, valDataset, testDataset = createLoaders(trainData, valData, testData, predicting_window)
    niter = len(trainDataset)

    train_mse = []
    test_mse = []
    val_mse = []

    train_mae = []
    test_mae = []
    val_mae = []

    for e in range(n_epochs):
        # one epoch on train set
        transformer.train()
        sum_train_loss = 0.0
        for x,y in trainDataset:
            S = x.shape[1]
            mask = create_look_ahead_mask(S)
            out, _ = transformer(x, mask)
            loss = torch.nn.MSELoss()(out, y)
            sum_train_loss += loss.item()
            loss.backward()
            optimizer.step()

            if e == n_epochs-1:
                train_mse.append(torch.nn.MSELoss()(out*std+mean, y*std+mean))
                train_mae.append(torch.nn.L1Loss()(out*std+mean, y*std+mean))

        losses.append(sum_train_loss / niter)

        # Evaluate on val set
        transformer.eval()
        sum_val_loss = 0.0
        for i, (x, y) in enumerate(valDataset):
            S = x.shape[1]
            mask = create_look_ahead_mask(S)
            out, _ = transformer(x, mask)
            loss = torch.nn.MSELoss()(out, y)
            sum_val_loss += loss.item()
            if e == n_epochs-1:
                val_mse.append(torch.nn.MSELoss()(out*std+mean, y*std+mean))
                val_mae.append(torch.nn.L1Loss()(out*std+mean, y*std+mean))

        val_losses.append(sum_val_loss / (i + 1))
        transformer.eval()
        sum_test_loss = 0.0
        for i, (x, y) in enumerate(testDataset):
            S = x.shape[1]
            mask = create_look_ahead_mask(S)
            out, _ = transformer(x, mask)
            loss = torch.nn.MSELoss()(out, y)
            sum_test_loss += loss.item()

            if e == n_epochs-1:
                test_mse.append(torch.nn.MSELoss()(out*std+mean, y*std+mean))
                test_mae.append(torch.nn.L1Loss()(out*std+mean, y*std+mean))
        test_losses.append(sum_test_loss / (i + 1))



    total_train_rmse.append(np.mean(np.sqrt([x.cpu().detach() for x in train_mse])))
    total_test_rmse.append(np.mean(np.sqrt([x.cpu().detach() for x in test_mse])))
    total_val_rmse.append(np.mean(np.sqrt([x.cpu().detach() for x in val_mse])))
    total_time.append(time.time()-t0)

    total_train_mae.append(np.mean([x.cpu().detach() for x in train_mae]))
    total_test_mae.append(np.mean([x.cpu().detach() for x in test_mae]))
    total_val_mae.append(np.mean([x.cpu().detach() for x in val_mae]))

# %%
x_ticks = range(1, 32)
plt.plot(x_ticks, total_train_rmse, '-o', label='Train')
plt.plot(x_ticks, total_val_rmse, '-o', label='Validation')
plt.plot(x_ticks, total_test_rmse, '-o', label='Test')

plt.title("RMSE evolution for different prediction horizon (Transformer)")
plt.xlabel("Prediction Horizon")
plt.ylabel("RMSE")
plt.legend()
plt.show()

# %%
x_ticks = range(1, 32)
plt.plot(x_ticks, total_train_mae, '-o', label='Train')
plt.plot(x_ticks, total_val_mae, '-o', label='Validation')
plt.plot(x_ticks, total_test_mae, '-o', label='Test')

plt.title("MAE evolution for different prediction horizon (Transformer)")
plt.xlabel("Prediction Horizon")
plt.ylabel("MAE")
plt.legend()
plt.show()

# %%
transformer_longterm_rmse = total_test_rmse
transformer_longterm_mae = total_test_mae

# %%
x_ticks = range(1, 32)
plt.plot(x_ticks, total_time, '-o')

plt.xlabel("Prediction Horizon")
plt.ylabel("Training times (seconds)")
plt.title("Transformer Training times")
plt.show()

# %% [markdown]
# # Longterm comparison

# %%
plt.plot(x_ticks, lstm_longterm_mae, '-o', label='LSTM')
plt.plot(x_ticks, rnn_longterm_mae, '-o', label='RNN')
plt.plot(x_ticks, transformer_longterm_mae,'-o',  label='Transformer')

plt.legend()
plt.xlabel("Prediction Horizon")
plt.title("MAE Longterm predictions Model Comparison")
plt.ylabel("MAE")
plt.show()

# %%
plt.plot(x_ticks, lstm_longterm_rmse, '-o', label='LSTM')
plt.plot(x_ticks, rnn_longterm_rmse, '-o', label='RNN')
plt.plot(x_ticks, transformer_longterm_rmse, '-o', label='Transformer')

plt.legend()
plt.xlabel("Prediction Horizon")
plt.ylabel("RMSE")
plt.title("RMSE Longterm predictions Model Comparison")
plt.show()

# %% [markdown]
# # Stock investment Simmulation

# %%
# Model will predict if we should invest on google stock a given day. We will compare those decisions with what we know we should have done

predict_window = 23 # We will predict 23 days ahead
n_lagged = 50

hidden_layer_neurons = 500
batch_size = 32
epochs = 100
learning_rate = 0.0005

# frame as supervised learning
reframed = series_to_supervised(df, n_lagged, predict_window)

# Dropping future variables
# At time "t", we only have Open(t) and want to predict Close(t), so we can drop High(t), Volume(t) and Low(t)
# Also we will drop Open(t-1) because each time step needs to have exactly 4 variables. If we add more time steps we will have
# a remaining Variable (Open(t)) to spare, so we will replace Open(t-1) with Open(t) for the first lagged variable.
reframed.drop(['High(t)', 'Low(t)', 'Volume(t)', 'Open(t-'+str(n_lagged)+')'], axis=1, inplace=True)
reframed.drop(['High(t+'+str(i)+')' for i in range(1, predict_window)], axis=1, inplace=True)
reframed.drop(['Low(t+'+str(i)+')' for i in range(1, predict_window)], axis=1, inplace=True)
reframed.drop(['Open(t+'+str(i)+')' for i in range(1, predict_window)], axis=1, inplace=True)
reframed.drop(['Volume(t+'+str(i)+')' for i in range(1, predict_window)], axis=1, inplace=True)


# Data splitting
train_X, train_y = reframed.iloc[:train_samples, :-predict_window].values, reframed.iloc[:train_samples, -predict_window:].values
val_X, val_y = reframed.iloc[train_samples:val_samples, :-predict_window].values, reframed.iloc[train_samples:val_samples, -predict_window:].values
test_X, test_y = reframed.iloc[val_samples:, :-predict_window].values, reframed.iloc[val_samples:, -predict_window:].values

# Reshaping for LSTM
train_X = train_X.reshape((train_X.shape[0], n_lagged, input_vars))
val_X = val_X.reshape((val_X.shape[0], n_lagged, input_vars))
test_X = test_X.reshape((test_X.shape[0], n_lagged, input_vars))

# Defining model for LSTM
optimizer = Adam(learning_rate=learning_rate)
model = Sequential()
model.add(LSTM(hidden_layer_neurons, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(predict_window)) # Output layer
model.compile(loss='mse', optimizer=optimizer)

# Fit network
t0 = time.time()
model.fit(train_X, train_y, epochs=epochs, batch_size=batch_size,
          validation_data=(val_X, val_y), shuffle=False,
          callbacks = [early_stopping])
t1 = time.time()

train_times.append(t1-t0)

# Predictions
yhat_test = model.predict(test_X)*std + mean
# Out:
# Epoch 1/100
# 79/79 [==============================] - 3s 15ms/step - loss: 0.1192 - val_loss: 0.5403
# Epoch 2/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.1069 - val_loss: 0.1437
# Epoch 3/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.0731 - val_loss: 0.1072
# Epoch 4/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.0621 - val_loss: 0.2205
# Epoch 5/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.0566 - val_loss: 0.2308
# Epoch 6/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.0447 - val_loss: 0.2298
# Epoch 7/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.0423 - val_loss: 0.0652
# Epoch 8/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0362 - val_loss: 0.1054
# Epoch 9/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0364 - val_loss: 0.1167
# Epoch 10/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0372 - val_loss: 0.0994
# Epoch 11/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0342 - val_loss: 0.1050
# Epoch 12/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0392 - val_loss: 0.0731
# Epoch 13/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0331 - val_loss: 0.0949
# 8/8 [==============================] - 0s 5ms/step

# %%
starting_budget = 1000

# %%
# Case 1: We invest when the testing period starts and sell when it ends
first_value = test_X[0][-1][-1]*std + mean
number_of_actions = starting_budget / first_value

last_value = test_X[-1][-1][-1]*std+mean
final_budget = last_value * number_of_actions
final_budget
# Out:
# 1298.6064621962976

# %%
# Case 2: Using the model to predict
# Strategy: Starting at time step t, we calculate the closing price for the next t+23 steps
# We set the selling time step at the point when the predicted closing price is maximal.
# If current time step is already a maximum, we do not buy and go to the next time step. Repeat the process
# If we find a maximal closing price, we simulate that we sell on that day regardless of the closing price and use the budget to
# repeat the proces

# The maximal investment will be of 500
current_time_step = 0
current_budget = 1000
success = 0

buying_arr = []
selling_arr = []
budgets_arr = []

while True:
    if current_time_step >= test_X.shape[0]:
        break

    # Calculating next 23 days closing price
    yhat = model.predict(test_X[[current_time_step]])

    # Should we buy?
    pos = np.argmax(yhat[0])
    max_value = np.max(yhat[0])

    if max_value > test_X[current_time_step][-1][-1]: # If the maximal closing price is higher than today's opening time
        buying_arr.append(current_time_step) # Shows when we buy

        if current_time_step + pos >= test_X.shape[0]:
            break
        if test_X[current_time_step][-1][-1] < test_y[current_time_step + pos][0]:
            success += 1

        # Buy
        actions = current_budget / (test_X[current_time_step][-1][-1]*std+mean)

        # Sell
        current_budget = actions * (test_y[current_time_step + pos][0] * std + mean)
        current_time_step += pos
        budgets_arr.append(current_budget)
        selling_arr.append(current_time_step)

    else:
        current_time_step += 1
# Out:
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step

# %%
current_budget
# Out:
# 1327.693528554246

# %%
success / len(buying_arr)
# Out:
# 0.6206896551724138

# %%
testing_df = df.iloc[val_samples+50:, 3]

plt.plot(testing_df.iloc[selling_arr].index, budgets_arr, '-o')
plt.xticks(rotation=90)

plt.ylabel("Stock price")
plt.xlabel("Date")
plt.title("Budget evolution")
plt.show()

# %%
testing_df = df.iloc[val_samples+50:, 3]

plt.plot(testing_df.index, testing_df*std + mean, label='Stock market real value')
plt.scatter(testing_df.iloc[buying_arr].index, testing_df.iloc[buying_arr]*std + mean, alpha = 0.5, c='red', label='Buying')
plt.scatter(testing_df.iloc[selling_arr].index, testing_df.iloc[selling_arr]*std + mean, alpha = 0.5, c='green', label='Selling')

plt.title("Model decisions comparison")
plt.ylabel("Google stock price")
plt.xlabel("Dates")
plt.legend()
plt.show()
